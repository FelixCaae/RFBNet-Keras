# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"
import copy
import random
from matplotlib import pyplot as plt
import numpy as np
#From keras
import keras
from keras.models import load_model
# from keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
from keras import optimizers,regularizers
from keras.utils import multi_gpu_model
from keras import backend as K
from keras.callbacks import *

# From ssd_keras
from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms
from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
import ssd_encoder_decoder.ssd_output_decoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections
from SSD_loss import SSDLoss
from eval_utils.average_precision_evaluator import Evaluator
from importlib import reload
#import cv2
from detector_help import process_y,post_process,prior_box
import detection_nets,classification_nets
import tensorflow as tf
from matplotlib import pyplot as plt
from drawing import *
from detection_nets import load_mobilenetv2
# %matplotlib inline

# %% [markdown]
# ### Set model config

# %%
input_H = 300
input_W = 300
input_C = 3
input_shape = (input_H, input_W, input_C)
root_path = "/home/cai/dataset/VOCdevkit"
aspect_ratios = [[2,3],
                 [2,3],
                 [2,3],
                 [2,3],
                 [2],
                 [2]]

mean_color = [123, 117, 104] 
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
num_classes = 20 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
variances = [0.1, 0.1, 0.2, 0.2]
# scale = [0.07, 0.17, 0.33, 0.51, 0.67, 0.87, 1.05]
scale = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05]

# %% [markdown]
# ### Build model

# %%
reload(detection_nets)
K.clear_session()
build_model = detection_nets.build_ssdlite
#Don`t tune learning rate here because we will use a lr scheduler in callbacks
#Orignal paper used SGD but according to the author of ssd_keras, use adam is better 
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3,alpha=1.0)
base_model = load_mobilenetv2()
#     base_model.summary()
prior_config =  [2 + len(ar) * 2 for ar in aspect_ratios]  # number of boxes per feature map location
# source_layer = "block_12_expand"
model = build_model(base_model = base_model,
               prior_config = prior_config,
#                source_layer_name_1 = "block_5_add",
               source_layer_name_2 = "block_12_add",
               num_classes = num_classes)


# for layer in model.layers[:120]:
#     layer.trainable = Fals
model = detection_nets.preprocess(input_shape,model,mean_color,swap_channels)
# model = multi_gpu_model(model,gpus=2) #Comment it if don`t use multi_gpu 
model.compile(adam,
              loss=ssd_loss.loss,
              metrics = [ssd_loss.class_loss,ssd_loss.loc_loss]
              )
print(model_name,'has been built ')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 301, 301, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 150, 150, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 150, 150, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 150, 150, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 150, 150, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 150, 150, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 150, 150, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 150, 150, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 150, 150, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 150, 150, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 150, 150, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 150, 150, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 151, 151, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 75, 75, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 75, 75, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 75, 75, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 75, 75, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None,
# __________________________________________________________________________________________________
# extra_6_bn (BatchNormalization) (None, 1, 1, 128)    512         extra_6_conv[0][0]
# __________________________________________________________________________________________________
# conf_0_conv (SeparableConv2D)   (None, 38, 38, 126)  4320        block_5_add[0][0]
# __________________________________________________________________________________________________
# conf_1_conv (SeparableConv2D)   (None, 10, 10, 126)  172800      out_relu[0][0]
# __________________________________________________________________________________________________
# conf_2_conv (SeparableConv2D)   (None, 5, 5, 126)    69120       extra_3_bn[0][0]
# __________________________________________________________________________________________________
# conf_3_conv (SeparableConv2D)   (None, 3, 3, 126)    34560       extra_4_bn[0][0]
# __________________________________________________________________________________________________
# conf_4_conv (SeparableConv2D)   (None, 3, 3, 84)     23808       extra_5_bn[0][0]
# __________________________________________________________________________________________________
# conf_5_conv (SeparableConv2D)   (None, 1, 1, 84)     11904       extra_6_bn[0][0]
# __________________________________________________________________________________________________
# conf_0_bn (BatchNormalization)  (None, 38, 38, 126)  504         conf_0_conv[0][0]
# __________________________________________________________________________________________________
# conf_1_bn (BatchNormalization)  (None, 10, 10, 126)  504         conf_1_conv[0][0]
# __________________________________________________________________________________________________
# conf_2_bn (BatchNormalization)  (None, 5, 5, 126)    504         conf_2_conv[0][0]
# __________________________________________________________________________________________________
# conf_3_bn (BatchNormalization)  (None, 3, 3, 126)    504         conf_3_conv[0][0]
# __________________________________________________________________________________________________
# conf_4_bn (BatchNormalization)  (None, 3, 3, 84)     336         conf_4_conv[0][0]
# __________________________________________________________________________________________________
# conf_5_bn (BatchNormalization)  (None, 1, 1, 84)     336         conf_5_conv[0][0]
# __________________________________________________________________________________________________
# loc_0_conv (SeparableConv2D)    (None, 38, 38, 24)   1056        block_5_add[0][0]
# __________________________________________________________________________________________________
# loc_1_conv (SeparableConv2D)    (None, 10, 10, 24)   42240       out_relu[0][0]
# __________________________________________________________________________________________________
# loc_2_conv (SeparableConv2D)    (None, 5, 5, 24)     16896       extra_3_bn[0][0]
# __________________________________________________________________________________________________
# loc_3_conv (SeparableConv2D)    (None, 3, 3, 24)     8448        extra_4_bn[0][0]
# __________________________________________________________________________________________________
# loc_4_conv (SeparableConv2D)    (None, 3, 3, 16)     6400        extra_5_bn[0][0]
# __________________________________________________________________________________________________
# loc_5_conv (SeparableConv2D)    (None, 1, 1, 16)     3200        extra_6_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_0 (Reshape)        (None, 8664, 21)     0           conf_0_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_1 (Reshape)        (None, 600, 21)      0           conf_1_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_2 (Reshape)        (None, 150, 21)      0           conf_2_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_3 (Reshape)        (None, 54, 21)       0           conf_3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_4 (Reshape)        (None, 36, 21)       0           conf_4_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_5 (Reshape)        (None, 4, 21)        0           conf_5_bn[0][0]
# __________________________________________________________________________________________________
# loc_0_bn (BatchNormalization)   (None, 38, 38, 24)   96          loc_0_conv[0][0]
# __________________________________________________________________________________________________
# loc_1_bn (BatchNormalization)   (None, 10, 10, 24)   96          loc_1_conv[0][0]
# __________________________________________________________________________________________________
# loc_2_bn (BatchNormalization)   (None, 5, 5, 24)     96          loc_2_conv[0][0]
# __________________________________________________________________________________________________
# loc_3_bn (BatchNormalization)   (None, 3, 3, 24)     96          loc_3_conv[0][0]
# __________________________________________________________________________________________________
# loc_4_bn (BatchNormalization)   (None, 3, 3, 16)     64          loc_4_conv[0][0]
# __________________________________________________________________________________________________
# loc_5_bn (BatchNormalization)   (None, 1, 1, 16)     64          loc_5_conv[0][0]
# __________________________________________________________________________________________________
# mbox_conf_merge (Concatenate)   (None, 9508, 21)     0           reshape_conf_0[0][0]
#                                                                  reshape_conf_1[0][0]
#                                                                  reshape_conf_2[0][0]
#                                                                  reshape_conf_3[0][0]
#                                                                  reshape_conf_4[0][0]
#                                                                  reshape_conf_5[0][0]
# __________________________________________________________________________________________________
# reshape_loc_0 (Reshape)         (None, 8664, 4)      0           loc_0_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_1 (Reshape)         (None, 600, 4)       0           loc_1_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_2 (Reshape)         (None, 150, 4)       0           loc_2_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_3 (Reshape)         (None, 54, 4)        0           loc_3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_4 (Reshape)         (None, 36, 4)        0           loc_4_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_5 (Reshape)         (None, 4, 4)         0           loc_5_bn[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, 9508, 21)     0           mbox_conf_merge[0][0]
# __________________________________________________________________________________________________
# mbox_loc_merge (Concatenate)    (None, 9508, 4)      0           reshape_loc_0[0][0]
#                                                                  reshape_loc_1[0][0]
#                                                                  reshape_loc_2[0][0]
#                                                                  reshape_loc_3[0][0]
#                                                                  reshape_loc_4[0][0]
#                                                                  reshape_loc_5[0][0]
# __________________________________________________________________________________________________
# mbox_pred_merge (Concatenate)   (None, 9508, 25)     0           softmax_1[0][0]
#                                                                  mbox_loc_merge[0][0]
# ==================================================================================================
# Total params: 3,566,016
# Trainable params: 3,528,000
# Non-trainable params: 38,016
# __________________________________________________________________________________________________
# ssdlite_mn2_L has been built

# %% [markdown]
# ### Load previously trained models

# %%
K.clear_session() # Clear previous models from memory.

model_path = "saved_weights/ssdlite_mn2_L_pascal_07+12_epoch-74_loss-2.3138_val_loss-2.6406.h5"
ssd_loss = SSDLoss(neg_pos_ratio=3,alpha=1.0)
model = load_model(model_path,custom_objects={'loss': ssd_loss.loss,'class_loss':ssd_loss.class_loss,'loc_loss':ssd_loss.loc_loss})
print("load model from",model_path)
# Out:
# load model from saved_weights/ssdlite_mn2_L_pascal_07+12_epoch-74_loss-2.3138_val_loss-2.6406.h5

# %%
model.layers[-1].summary()                       #Comment this line if you don`t want to show summary every time you build your model
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None,
# extra_5_conv (SeparableConv2D)  (None, 3, 3, 256)    67840       extra_4_bn[0][0]
# __________________________________________________________________________________________________
# extra_5_bn (BatchNormalization) (None, 3, 3, 256)    1024        extra_5_conv[0][0]
# __________________________________________________________________________________________________
# extra_6_conv (SeparableConv2D)  (None, 1, 1, 128)    35072       extra_5_bn[0][0]
# __________________________________________________________________________________________________
# extra_6_bn (BatchNormalization) (None, 1, 1, 128)    512         extra_6_conv[0][0]
# __________________________________________________________________________________________________
# conf_0_conv (SeparableConv2D)   (None, 19, 19, 126)  77760       block_12_expand[0][0]
# __________________________________________________________________________________________________
# conf_1_conv (SeparableConv2D)   (None, 10, 10, 126)  172800      out_relu[0][0]
# __________________________________________________________________________________________________
# conf_2_conv (SeparableConv2D)   (None, 5, 5, 126)    69120       extra_3_bn[0][0]
# __________________________________________________________________________________________________
# conf_3_conv (SeparableConv2D)   (None, 3, 3, 126)    34560       extra_4_bn[0][0]
# __________________________________________________________________________________________________
# conf_4_conv (SeparableConv2D)   (None, 3, 3, 84)     23808       extra_5_bn[0][0]
# __________________________________________________________________________________________________
# conf_5_conv (SeparableConv2D)   (None, 1, 1, 84)     11904       extra_6_bn[0][0]
# __________________________________________________________________________________________________
# conf_0_bn (BatchNormalization)  (None, 19, 19, 126)  504         conf_0_conv[0][0]
# __________________________________________________________________________________________________
# conf_1_bn (BatchNormalization)  (None, 10, 10, 126)  504         conf_1_conv[0][0]
# __________________________________________________________________________________________________
# conf_2_bn (BatchNormalization)  (None, 5, 5, 126)    504         conf_2_conv[0][0]
# __________________________________________________________________________________________________
# conf_3_bn (BatchNormalization)  (None, 3, 3, 126)    504         conf_3_conv[0][0]
# __________________________________________________________________________________________________
# conf_4_bn (BatchNormalization)  (None, 3, 3, 84)     336         conf_4_conv[0][0]
# __________________________________________________________________________________________________
# conf_5_bn (BatchNormalization)  (None, 1, 1, 84)     336         conf_5_conv[0][0]
# __________________________________________________________________________________________________
# loc_0_conv (SeparableConv2D)    (None, 19, 19, 24)   19008       block_12_expand[0][0]
# __________________________________________________________________________________________________
# loc_1_conv (SeparableConv2D)    (None, 10, 10, 24)   42240       out_relu[0][0]
# __________________________________________________________________________________________________
# loc_2_conv (SeparableConv2D)    (None, 5, 5, 24)     16896       extra_3_bn[0][0]
# __________________________________________________________________________________________________
# loc_3_conv (SeparableConv2D)    (None, 3, 3, 24)     8448        extra_4_bn[0][0]
# __________________________________________________________________________________________________
# loc_4_conv (SeparableConv2D)    (None, 3, 3, 16)     6400        extra_5_bn[0][0]
# __________________________________________________________________________________________________
# loc_5_conv (SeparableConv2D)    (None, 1, 1, 16)     3200        extra_6_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_0 (Reshape)        (None, 2166, 21)     0           conf_0_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_1 (Reshape)        (None, 600, 21)      0           conf_1_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_2 (Reshape)        (None, 150, 21)      0           conf_2_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_3 (Reshape)        (None, 54, 21)       0           conf_3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_4 (Reshape)        (None, 36, 21)       0           conf_4_bn[0][0]
# __________________________________________________________________________________________________
# reshape_conf_5 (Reshape)        (None, 4, 21)        0           conf_5_bn[0][0]
# __________________________________________________________________________________________________
# loc_0_bn (BatchNormalization)   (None, 19, 19, 24)   96          loc_0_conv[0][0]
# __________________________________________________________________________________________________
# loc_1_bn (BatchNormalization)   (None, 10, 10, 24)   96          loc_1_conv[0][0]
# __________________________________________________________________________________________________
# loc_2_bn (BatchNormalization)   (None, 5, 5, 24)     96          loc_2_conv[0][0]
# __________________________________________________________________________________________________
# loc_3_bn (BatchNormalization)   (None, 3, 3, 24)     96          loc_3_conv[0][0]
# __________________________________________________________________________________________________
# loc_4_bn (BatchNormalization)   (None, 3, 3, 16)     64          loc_4_conv[0][0]
# __________________________________________________________________________________________________
# loc_5_bn (BatchNormalization)   (None, 1, 1, 16)     64          loc_5_conv[0][0]
# __________________________________________________________________________________________________
# mbox_conf_merge (Concatenate)   (None, 3010, 21)     0           reshape_conf_0[0][0]
#                                                                  reshape_conf_1[0][0]
#                                                                  reshape_conf_2[0][0]
#                                                                  reshape_conf_3[0][0]
#                                                                  reshape_conf_4[0][0]
#                                                                  reshape_conf_5[0][0]
# __________________________________________________________________________________________________
# reshape_loc_0 (Reshape)         (None, 2166, 4)      0           loc_0_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_1 (Reshape)         (None, 600, 4)       0           loc_1_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_2 (Reshape)         (None, 150, 4)       0           loc_2_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_3 (Reshape)         (None, 54, 4)        0           loc_3_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_4 (Reshape)         (None, 36, 4)        0           loc_4_bn[0][0]
# __________________________________________________________________________________________________
# reshape_loc_5 (Reshape)         (None, 4, 4)         0           loc_5_bn[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, 3010, 21)     0           mbox_conf_merge[0][0]
# __________________________________________________________________________________________________
# mbox_loc_merge (Concatenate)    (None, 3010, 4)      0           reshape_loc_0[0][0]
#                                                                  reshape_loc_1[0][0]
#                                                                  reshape_loc_2[0][0]
#                                                                  reshape_loc_3[0][0]
#                                                                  reshape_loc_4[0][0]
#                                                                  reshape_loc_5[0][0]
# __________________________________________________________________________________________________
# mbox_pred_merge (Concatenate)   (None, 3010, 25)     0           softmax_1[0][0]
#                                                                  mbox_loc_merge[0][0]
# ==================================================================================================
# Total params: 3,657,408
# Trainable params: 3,619,392
# Non-trainable params: 38,016
# __________________________________________________________________________________________________

# %% [markdown]
# ### Define featue map as predictor size

# %%
feature_map_300 = [layer.output.shape.as_list()[1:3] for layer in model.layers[-1].layers if ('loc_' in layer.name and 'conv' in layer.name)]
# priors = prior_box(feature_map,aspect_ratios,scale = scale)

# %%
#Define class_names
class_names = ['background',
           'aeroplane', 'bicycle', 'bird', 'boat',
           'bottle', 'bus', 'car', 'cat',
           'chair', 'cow', 'diningtable', 'dog',
           'horse', 'motorbike', 'person', 'pottedplant',
           'sheep', 'sofa', 'train', 'tvmonitor']

force_create_dataset = False #Force data generator to load dataset from source

# %% [markdown]
# ## Load Dataset

# %%
root_path = '/home/cai/dataset/VOCdevkit'
trainset_hdf5_path = 'dataset_pascal_voc_07+12_trainval.h5'
valset_hdf5_path = 'dataset_pascal_voc_07_test.h5'

# The directories that contain the images.
VOC_2007_images_dir      = root_path + '/VOC2007/JPEGImages/'
VOC_2012_images_dir      = root_path + '/VOC2012/JPEGImages/'

# The directories that contain the annotations.
VOC_2007_annotations_dir      = root_path + '/VOC2007/Annotations/'
VOC_2012_annotations_dir      = root_path + '/VOC2012/Annotations/'

# The paths to the image sets.
VOC_2007_train_image_set_filename    = root_path + '/VOC2007/ImageSets/Main/train.txt'
VOC_2012_train_image_set_filename    = root_path + '/VOC2012/ImageSets/Main/train.txt'
VOC_2007_val_image_set_filename      = root_path + '/VOC2007/ImageSets/Main/val.txt'
VOC_2012_val_image_set_filename      = root_path + '/VOC2012/ImageSets/Main/val.txt'
VOC_2007_trainval_image_set_filename = root_path + '/VOC2007/ImageSets/Main/trainval.txt'
VOC_2012_trainval_image_set_filename = root_path + '/VOC2012/ImageSets/Main/trainval.txt'
VOC_2007_test_image_set_filename     = root_path + '/VOC2007/ImageSets/Main/test.txt'

if os.path.isfile(trainset_hdf5_path) and os.path.isfile(valset_hdf5_path) and not force_create_dataset:
    #Load dataset from created hdf5_dataset
    train_dataset = DataGenerator(hdf5_dataset_path = trainset_hdf5_path)
    val_dataset = DataGenerator(hdf5_dataset_path = valset_hdf5_path)
else:
    train_dataset = DataGenerator()
    val_dataset = DataGenerator()
    
    train_dataset.parse_xml(images_dirs=[VOC_2007_images_dir,
                                         VOC_2012_images_dir],
                            image_set_filenames=[VOC_2007_trainval_image_set_filename,
                                                 VOC_2012_trainval_image_set_filename],
                            annotations_dirs=[VOC_2007_annotations_dir,
                                              VOC_2012_annotations_dir],
                            classes=class_names,
                            include_classes='all',
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                          image_set_filenames=[VOC_2007_test_image_set_filename],
                          annotations_dirs=[VOC_2007_annotations_dir],
                          classes=class_names,
                          include_classes='all',
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)
    train_dataset.create_hdf5_dataset(file_path=trainset_hdf5_path,
                                      resize=False,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=valset_hdf5_path,
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)
# Out:
# Loading labels: 100%|██████████| 16551/16551 [00:07<00:00, 2150.34it/s]
# Loading image IDs: 100%|██████████| 16551/16551 [00:01<00:00, 9567.48it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 16551/16551 [00:02<00:00, 7209.39it/s]
# Loading labels: 100%|██████████| 4952/4952 [00:02<00:00, 2345.06it/s]
# Loading image IDs: 100%|██████████| 4952/4952 [00:00<00:00, 9031.87it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 4952/4952 [00:00<00:00, 7262.86it/s]

# %% [markdown]
# ## Data Augment

# %%
import detector_help
reload(detector_help)
from detector_help import *
import data_augment
reload(data_augment)
from data_augment import *

batch_size = 32
ssd_data_augmentation = SSDDataAugmentation(img_height=input_H,
                                            img_width=input_W,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=input_H, width=input_W)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
priors = prior_box(feature_map_300,aspect_ratios,scale = scale,clip = False)
label_encoder = LabelEncoder(num_classes,priors,variances,input_H,input_W)

# ssd_input_encoder = SSDInputEncoder(img_height=input_H,
#                                     img_width=input_W,
#                                     n_classes=num_classes,
#                                     predictor_sizes=feature_map,
#                                     scales=scales,
#                                     aspect_ratios_per_layer=aspect_ratios,
#                                     two_boxes_for_ar1=two_boxes_for_ar1,
#                                     steps=steps,
#                                     offsets=offsets,
#                                     clip_boxes=clip_boxes,
#                                     variances=variances,
#                                     matching_type='multi',
#                                     pos_iou_threshold=0.5,
#                                     neg_iou_limit=0.5,
#                                     normalize_coords=normalize_coords)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=label_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=label_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()
print("Number of priors:\t{:>6}".format(len(priors)))
print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of priors:	  3010
# Number of images in the training dataset:	 16551
# Number of images in the validation dataset:	  4952

# %% [markdown]
# ## Draw a batch of images(optional)

# %%
train_flow_origin = train_dataset.generate(batch_size = 4,
                                           transformations=[], 
                                           label_encoder = label_encoder,
                                           returns = ['original_images','original_labels'])
images,labels = next(train_flow_origin)
for img,label in zip(images, labels):
    draw_detection(img,label,class_names)

# %% [markdown]
# ### Debug encoder-decoder and data augment

# %%
import detector_help
reload(detector_help)
import ssd_encoder_decoder.ssd_output_decoder
reload(ssd_encoder_decoder.ssd_output_decoder)
from ssd_encoder_decoder.ssd_output_decoder import decode_detections
from detector_help import LabelEncoder
priors = prior_box(feature_map_300,aspect_ratios,scale = scale,clip = False)
label_encoder = LabelEncoder(num_classes,priors,variances,input_H,input_W)
train_flow_encode = train_dataset.generate(batch_size = 4,
                                           transformations= [convert_to_3_channels,
                                                      resize], 
                                           label_encoder = label_encoder,
                                           shuffle = False,
                                           returns=["processed_images","processed_labels","encoded_labels"])

images,enc_labels,proc_labels = next(train_flow_encode)
enc_labels_custom = detector_help.post_process(enc_labels,
                                               priors,
                                               variances,
                                               num_classes,
                                               input_H,input_W, 
                                               score_thresh = 0.06,   
                                               iou_thresh = 0.01,
                                               top_k = 1000) # Use top_k as 1000 because all gt labels`s conf are 1
enc_labels_default = decode_detections(enc_labels,
                  priors,
                  np.array(variances),
                  img_height = input_H,
                  img_width = input_W,
                  confidence_thresh = 0.06,
                  iou_threshold = 0.45)

for img,enc_default_label,enc_custom_label,proc_label in zip(images,enc_labels_default,enc_labels_custom,proc_labels):
#     print(enc_custom_label)
    draw_detection(img, proc_label, class_names, color = 'green')
    #plt.title('Default decoder')
    #draw_detection(img, enc_default_label, class_names, color = 'red')
   # plt.title('Custom decoder')
    draw_detection(img, enc_default_label, class_names, color = 'purple')

# %%
import time
base_img = np.zeros((300,300,3))
plt.imshow(base_img)
current_axis = plt.gca()
print(len(priors))
for k,box in enumerate(priors[4:6*38:6]):
#     plt.imshow(base_img)
#     current_axis = plt.gca()
#     if k%100 == 0:
#         base_img = np.zeros((300,300,3))
#         #plt.imshow(base_img)
#         current_axis = plt.gca()
    xmid,ymid,w,h = box[-4:]
    xmid *= 300
    ymid *= 300
    w *= 300
    h *= 300
    if k < 1000:
        color = 'red'
    else:
        color = 'green'
    current_axis.add_patch(plt.Rectangle((xmid - w/2, ymid - h/2), w,h, color=color, fill=False, linewidth=2))

# %% [markdown]
# ### Set training params

# %%
#If load weights from files,initial_epoch need to be set to the next epoch to be trained.
model_name = "ssdlite_mn2"
initial_epoch = 74
final_epochs = 120
steps_per_epoch = 1000
plot = True

# %% [markdown]
# ## Define callback function

# %%
#1. Set file path
weights_folder = 'saved_weights/'

if not os.path.isdir(weights_folder):
    os.mkdir(weights_folder)

checkpoint_filepath = weights_folder + model_name + '_pascal_07+12_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'
log_filepath = model_name + '_pascal_07+12_training_log.csv' 
#2. Define lr schedule function
def lr_schedule(epoch):
    if epoch < 30:
        return 1e-3
    elif epoch < 60:
        return 5e-4
    elif epoch < 90:
        return 1e-4
    else:
        return 5e-4
#3. ## Define callbacks
model_checkpoint = ModelCheckpoint(filepath = checkpoint_filepath,
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=5)

csv_logger = CSVLogger(filename=log_filepath,
                           separator=',',
                           append=True)
lr_schedule = LearningRateScheduler(lr_schedule)
reduce_learning_rate = ReduceLROnPlateau(monitor='val_loss',
                                         factor=0.2,
                                         patience=8,
                                         verbose=1,
                                         epsilon=0.001,
                                         cooldown=0,
                                         min_lr=0.00001)    
terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             lr_schedule,
#              reduce_learning_rate,
             terminate_on_nan]
# callbacks = [csv_logger,learning_rate_scheduler]

# %% [markdown]
# ## Train the model

# %%
print('model name' ,model_name , \
       '\nstart fitting.. ' , 
       'inital epoch:', initial_epoch,
       'final epoch:', final_epochs,
       'epoch step:', steps_per_epoch,
       'plot_history:' ,plot, \
       '\ntrainset size:',  train_dataset.get_dataset_size(), ' batch_size', batch_size )     

validation_steps =  val_dataset.get_dataset_size() // batch_size
history = model.fit_generator(train_generator,
                              use_multiprocessing = True, 
                              steps_per_epoch = steps_per_epoch, 
                              validation_data = val_generator,
                              validation_steps = validation_steps, 
                              epochs = final_epochs,
                              callbacks = callbacks,
                              initial_epoch = initial_epoch)

if plot:
    plot_history(history)
    plt.savefig('./rfbmn2_300_pascal07+12_train.jpg')
# Out:
# model name ssdlite_mn2
# start fitting..  inital epoch: 74 final epoch: 120 epoch step: 1000 plot_history: True
# trainset size: 16551  batch_size 32
# Epoch 75/120
# 1000/1000 [==============================] - 956s 956ms/step - loss: 2.4470 - class_loss: 1.6701 - loc_loss: 0.7769 - val_loss: 2.7748 - val_class_loss: 1.9180 - val_loc_loss: 0.8567
# Epoch 76/120
# 1000/1000 [==============================] - 748s 748ms/step - loss: 2.3943 - class_loss: 1.6342 - loc_loss: 0.7601 - val_loss: 2.7639 - val_class_loss: 1.9124 - val_loc_loss: 0.8514
# Epoch 77/120
# 1000/1000 [==============================] - 750s 750ms/step - loss: 2.3909 - class_loss: 1.6361 - loc_loss: 0.7548 - val_loss: 2.7641 - val_class_loss: 1.9118 - val_loc_loss: 0.8524
# Epoch 78/120
# 1000/1000 [==============================] - 752s 752ms/step - loss: 2.3943 - class_loss: 1.6386 - loc_loss: 0.7557 - val_loss: 2.7653 - val_class_loss: 1.9131 - val_loc_loss: 0.8521
# Epoch 79/120
# 1000/1000 [==============================] - 750s 750ms/step - loss: 2.3896 - class_loss: 1.6376 - loc_loss: 0.7520 - val_loss: 2.7715 - val_class_loss: 1.9214 - val_loc_loss: 0.8501
#
# Epoch 00079: val_loss improved from inf to 2.77148, saving model to saved_weights/ssdlite_mn2_pascal_07+12_epoch-79_loss-2.3873_val_loss-2.7715.h5
# Epoch 80/120
# 1000/1000 [==============================] - 746s 746ms/step - loss: 2.3745 - class_loss: 1.6246 - loc_loss: 0.7499 - val_loss: 2.7597 - val_class_loss: 1.9117 - val_loc_loss: 0.8480
# Epoch 81/120
# 1000/1000 [==============================] - 750s 750ms/step - loss: 2.3805 - class_loss: 1.6301 - loc_loss: 0.7504 - val_loss: 2.7632 - val_class_loss: 1.9150 - val_loc_loss: 0.8483
# Epoch 82/120
# 1000/1000 [==============================] - 748s 748ms/step - loss: 2.3708 - class_loss: 1.6231 - loc_loss: 0.7477 - val_loss: 2.7776 - val_class_loss: 1.9267 - val_loc_loss: 0.8509
# Epoch 83/120
# 1000/1000 [==============================] - 746s 746ms/step - loss: 2.3666 - class_loss: 1.6202 - loc_loss: 0.7465 - val_loss: 2.7805 - val_class_loss: 1.9298 - val_loc_loss: 0.8508
# Epoch 84/120
#  540/1000 [===============>..............] - ETA: 5:30 - loss: 2.3485 - class_loss: 1.6078 - loc_loss: 0.7407
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  188/1000 [====>.........................] - ETA: 9:25 - loss: 2.3260 - class_loss: 1.5916 - loc_loss: 0.7343
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 343, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-6e1f2cb6cbd8> in <module>
#      15                               epochs = final_epochs,
#      16                               callbacks = callbacks,
# ---> 17                               initial_epoch = initial_epoch)
#      18
#      19 if plot:
#
# ~/.local/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1656             use_multiprocessing=use_multiprocessing,
#    1657             shuffle=shuffle,
# -> 1658             initial_epoch=initial_epoch)
#    1659
#    1660     @interfaces.legacy_generator_methods_support
#
# ~/.local/lib/python3.5/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# ~/.local/lib/python3.5/site-packages/keras/utils/data_utils.py in get(self)
#     700                 try:
#     701                     future = self.queue.get(block=True)
# --> 702                     inputs = future.get(timeout=30)
#     703                     self.queue.task_done()
#     704                 except mp.TimeoutError:
#
# /usr/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# /usr/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     295             else:
#     296                 if timeout > 0:
# --> 297                     gotit = waiter.acquire(True, timeout)
#     298                 else:
#     299                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/cai/.local/lib/python3.5/site-packages/keras/utils/data_utils.py", line 641, in next_sample
#     return six.next(_SHARED_SEQUENCES[uid])
#   File "/home/cai/project/RFBNet-Keras/data_generator/object_detection_2d_data_generator.py", line 1076, in generate
#     batch_X[i], batch_y[i] = transform(batch_X[i], batch_y[i])
#   File "/home/cai/project/RFBNet-Keras/data_generator/data_augmentation_chain_original_ssd.py", line 275, in __call__
#     image, labels = transform(image, labels)
#   File "/home/cai/project/RFBNet-Keras/data_generator/data_augmentation_chain_original_ssd.py", line 205, in __call__
#     image, labels = transform(image, labels)
#   File "/home/cai/project/RFBNet-Keras/data_generator/object_detection_2d_photometric_ops.py", line 80, in __call__
#     image = np.round(image, decimals=0).astype(np.uint8)
#   File "/home/cai/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py", line 2814, in round_
#     return around(a, decimals=decimals, out=out)
#   File "/home/cai/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py", line 2800, in around
#     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#   File "/home/cai/.local/lib/python3.5/site-packages/numpy/core/fromnumeric.py", line 51, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# KeyboardInterrupt

# %%
model.layers[-1].summary()

# %% [markdown]
# ### Evaluate

# %%
import eval_utils.average_precision_evaluator
reload(eval_utils.average_precision_evaluator)
from eval_utils.average_precision_evaluator import Evaluator

# %%
test_dataset = DataGenerator()
test_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                      image_set_filenames=[VOC_2007_test_image_set_filename],
                      annotations_dirs=[VOC_2007_annotations_dir],
                      classes=class_names,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=False,
                      ret=False)
print('Test size', test_dataset.get_dataset_size())
# Out:
# Processing image set 'test.txt': 100%|██████████| 4952/4952 [00:12<00:00, 382.39it/s]
# Test size 4952

# %%
evaluator = Evaluator(model=model,
                      n_classes=num_classes,
                      data_generator=test_dataset,
                      model_mode='training')

results = evaluator(img_height=input_H,
                    img_width=input_W,
                    batch_size=batch_size,
                    priors = priors,
                    variances = variances,
                    data_generator_mode='resize',
                    round_confidences=False,
                    matching_iou_threshold=0.5,
                    border_pixels='include',
                    sorting_algorithm='quicksort',
                    average_precision_mode='sample',
                    num_recall_points=11,
                    ignore_neutral_boxes=True,
                    return_precisions=True,
                    return_recalls=True,
                    return_average_precisions=True,
                    verbose=True)

mean_average_precision, average_precisions, precisions, recalls = results
# Out:
# Number of images in the evaluation dataset: 4952
#
#
#   0%|          | 0/155 [00:00<?, ?it/s]
# Producing predictions batch-wise:   0%|          | 0/155 [00:00<?, ?it/s]
# Producing predictions batch-wise:   1%|          | 1/155 [00:02<06:11,  2.41s/it]
# Producing predictions batch-wise:   1%|▏         | 2/155 [00:03<04:54,  1.92s/it]
# Producing predictions batch-wise:   2%|▏         | 3/155 [00:03<03:59,  1.57s/it]
# Producing predictions batch-wise:   3%|▎         | 4/155 [00:04<03:21,  1.34s/it]
# Producing predictions batch-wise:   3%|▎         | 5/155 [00:05<02:56,  1.17s/it]
# Producing predictions batch-wise:   4%|▍         | 6/155 [00:06<02:37,  1.06s/it]
# Producing predictions batch-wise:   5%|▍         | 7/155 [00:07<02:23,  1.03it/s]
# Producing predictions batch-wise:   5%|▌         | 8/155 [00:07<02:16,  1.07it/s]
# Producing predictions batch-wise:   6%|▌         | 9/155 [00:08<02:11,  1.11it/s]
# Producing predictions batch-wise:   6%|▋         | 10/155 [00:09<02:05,  1.15it/s]
# Producing predictions batch-wise:   7%|▋         | 11/155 [00:10<02:01,  1.19it/s]
# Producing predictions batch-wise:   8%|▊         | 12/155 [00:11<01:57,  1.21it/s]
# Producing predictions batch-wise:   8%|▊         | 13/155 [00:11<01:55,  1.23it/s]
# Producing predictions batch-wise:   9%|▉         | 14/155 [00:12<01:52,  1.25it/s]
# Producing predictions batch-wise:  10%|▉         | 15/155 [00:13<01:52,  1.25it/s]
# Producing predictions batch-wise:  10%|█         | 16/155 [00:14<01:54,  1.22it/s]
# Producing predictions batch-wise:  11%|█         | 17/155 [00:15<01:50,  1.25it/s]
# Producing predictions batch-wise:  12%|█▏        | 18/155 [00:15<01:48,  1.26it/s]
# Producing predictions batch-wise: 100%|██████████| 155/155 [02:05<00:00,  1.33it/s]
#   0%|          | 0/22671 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 1/20.:   0%|          | 0/22671 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 1/20.:   4%|▍         | 972/22671 [00:00<00:02, 9709.52it/s]
# Matching predictions to ground truth, class 1/20.:   9%|▉         | 2121/22671 [00:00<00:02, 10181.25it/s]
# Matching predictions to ground truth, class 1/20.:  14%|█▍        | 3250/22671 [00:00<00:01, 10489.66it/s]
# Matching predictions to ground truth, class 1/20.:  19%|█▉        | 4402/22671 [00:00<00:01, 10776.17it/s]
# Matching predictions to ground truth, class 1/20.:  25%|██▍       | 5614/22671 [00:00<00:01, 11145.66it/s]
# Matching predictions to ground truth, class 1/20.:  30%|███       | 6894/22671 [00:00<00:01, 11594.29it/s]
# Matching predictions to ground truth, class 1/20.:  36%|███▋      | 8227/22671 [00:00<00:01, 12062.76it/s]
# Matching predictions to ground truth, class 1/20.:  42%|████▏     | 9600/22671 [00:00<00:01, 12518.50it/s]
# Matching predictions to ground truth, class 1/20.:  49%|████▊     | 11021/22671 [00:00<00:00, 12981.53it/s]
# Matching predictions to ground truth, class 1/20.:  56%|█████▌    | 12586/22671 [00:01<00:00, 13680.59it/s]
# Matching predictions to ground truth, class 1/20.:  62%|██████▏   | 14091/22671 [00:01<00:00, 14063.40it/s]
# Matching predictions to ground truth, class 1/20.:  70%|██████▉   | 15766/22671 [00:01<00:00, 14772.72it/s]
# Matching predictions to ground truth, class 1/20.:  77%|███████▋  | 17483/22671 [00:01<00:00, 15417.11it/s]
# Matching predictions to ground truth, class 1/20.:  85%|████████▌ | 19315/22671 [00:01<00:00, 16184.99it/s]
# Matching predictions to ground truth, class 1/20.:  93%|█████████▎| 21170/22671 [00:01<00:00, 16827.51it/s]
# Matching predictions to ground truth, class 1/20.: 100%|██████████| 22671/22671 [00:01<00:00, 14388.51it/s]
#   0%|          | 0/8481 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 2/20.:   0%|          | 0/8481 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 2/20.:  13%|█▎        | 1081/8481 [00:00<00:00, 10809.86it/s]
# Matching predictions to ground truth, class 2/20.:  21%|██        | 1798/8481 [00:00<00:00, 9379.96it/s]
# Matching predictions to ground truth, class 2/20.:  37%|███▋      | 3096/8481 [00:00<00:00, 10230.98it/s]
# Matching predictions to ground truth, class 2/20.:  54%|█████▍    | 4568/8481 [00:00<00:00, 11258.25it/s]
# Matching predictions to ground truth, class 2/20.:  73%|███████▎  | 6171/8481 [00:00<00:00, 12362.10it/s]
# Matching predictions to ground truth, class 2/20.:  91%|█████████ | 7733/8481 [00:00<00:00, 13186.96it/s]
# Matching predictions to ground truth, class 2/20.: 100%|██████████| 8481/8481 [00:00<00:00, 13205.55it/s]
#   0%|          | 0/115311 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 3/20.:   0%|          | 0/115311 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 3/20.:   1%|          | 1018/115311 [00:00<00:11, 10177.95it/s]
# Matching predictions to ground truth, class 3/20.:   2%|▏         | 2248/115311 [00:00<00:10, 10733.46it/s]
# Matching predictions to ground truth, class 3/20.:   3%|▎         | 3489/115311 [00:00<00:09, 11184.26it/s]
# Matching predictions to ground truth, class 3/20.:   4%|▍         | 4689/115311 [00:00<00:09, 11415.84it/s]
# Matching predictions to ground truth, class 3/20.:   5%|▌         | 5972/115311 [00:00<00:09, 11805.62it/s]
# Matching predictions to ground truth, class 3/20.:   6%|▋         | 7264/115311 [00:00<00:08, 12115.73it/s]
# Matching predictions to ground truth, class 3/20.:   7%|▋         | 8552/115311 [00:00<00:08, 12332.51it/s]
# Matching predictions to ground truth, class 3/20.:   9%|▊         | 9874/115311 [00:00<00:08, 12585.34it/s]
# Matching predictions to ground truth, class 3/20.:  10%|▉         | 11190/115311 [00:00<00:08, 12752.13it/s]
# Matching predictions to ground truth, class 3/20.:  11%|█         | 12580/115311 [00:01<00:07, 13075.18it/s]
# Matching predictions to ground truth, class 3/20.:  12%|█▏        | 13865/115311 [00:01<00:07, 12923.23it/s]
# Matching predictions to ground truth, class 3/20.:  13%|█▎        | 15142/115311 [00:01<00:08, 12513.04it/s]
# Matching predictions to ground truth, class 3/20.:  14%|█▍        | 16681/115311 [00:01<00:07, 13255.76it/s]
# Matching predictions to ground truth, class 3/20.:  16%|█▋        | 18793/115311 [00:01<00:06, 14922.44it/s]
# Matching predictions to ground truth, class 3/20.:  18%|█▊        | 20487/115311 [00:01<00:06, 15474.34it/s]
# Matching predictions to ground truth, class 3/20.:  19%|█▉        | 22127/115311 [00:01<00:05, 15740.65it/s]
# Matching predictions to ground truth, class 3/20.:  21%|██        | 23888/115311 [00:01<00:05, 16254.26it/s]
# Matching predictions to ground truth, class 3/20.:  22%|██▏       | 25738/115311 [00:01<00:05, 16866.14it/s]
# Matching predictions to ground truth, class 3/20.:  24%|██▍       | 27624/115311 [00:01<00:05, 17417.65it/s]
# Matching predictions to ground truth, class 3/20.:  26%|██▌       | 29575/115311 [00:02<00:04, 17995.54it/s]
# Matching predictions to ground truth, class 3/20.:  27%|██▋       | 31521/115311 [00:02<00:04, 18410.01it/s]
# Matching predictions to ground truth, class 3/20.:  29%|██▉       | 33512/115311 [00:02<00:04, 18835.24it/s]
# Matching predictions to ground truth, class 3/20.:  31%|███       | 35726/115311 [00:02<00:04, 19718.08it/s]
# Matching predictions to ground truth, class 3/20.:  33%|███▎      | 37916/115311 [00:02<00:03, 20322.95it/s]
# Matching predictions to ground truth, class 3/20.:  35%|███▍      | 40173/115311 [00:02<00:03, 20943.36it/s]
# Matching predictions to ground truth, class 3/20.:  37%|███▋      | 42420/115311 [00:02<00:03, 21377.96it/s]
# Matching predictions to ground truth, class 3/20.:  39%|███▉      | 44704/115311 [00:02<00:03, 21795.62it/s]
# Matching predictions to ground truth, class 3/20.:  41%|████      | 47034/115311 [00:02<00:03, 22225.24it/s]
# Matching predictions to ground truth, class 3/20.:  43%|████▎     | 49268/115311 [00:02<00:03, 18656.08it/s]
# Matching predictions to ground truth, class 3/20.:  45%|████▍     | 51422/115311 [00:03<00:03, 19436.37it/s]
# Matching predictions to ground truth, class 3/20.:  47%|████▋     | 53917/115311 [00:03<00:02, 20815.52it/s]
# Matching predictions to ground truth, class 3/20.:  49%|████▉     | 56407/115311 [00:03<00:02, 21891.80it/s]
# Matching predictions to ground truth, class 3/20.:  51%|█████     | 58911/115311 [00:03<00:02, 22741.18it/s]
# Matching predictions to ground truth, class 3/20.:  53%|█████▎    | 61465/115311 [00:03<00:02, 23514.14it/s]
# Matching predictions to ground truth, class 3/20.:  56%|█████▌    | 64131/115311 [00:03<00:02, 24377.04it/s]
# Matching predictions to ground truth, class 3/20.:  58%|█████▊    | 66742/115311 [00:03<00:01, 24871.60it/s]
# Matching predictions to ground truth, class 3/20.:  60%|██████    | 69371/115311 [00:03<00:01, 25278.81it/s]
# Matching predictions to ground truth, class 3/20.:  62%|██████▏   | 71988/115311 [00:03<00:01, 25538.75it/s]
# Matching predictions to ground truth, class 3/20.:  65%|██████▍   | 74707/115311 [00:03<00:01, 26011.37it/s]
# Matching predictions to ground truth, class 3/20.:  67%|██████▋   | 77413/115311 [00:04<00:01, 26313.10it/s]
# Matching predictions to ground truth, class 3/20.:  70%|██████▉   | 80215/115311 [00:04<00:01, 26801.32it/s]
# Matching predictions to ground truth, class 3/20.:  72%|███████▏  | 83075/115311 [00:04<00:01, 27315.60it/s]
# Matching predictions to ground truth, class 3/20.:  74%|███████▍  | 85868/115311 [00:04<00:01, 27495.39it/s]
# Matching predictions to ground truth, class 3/20.:  77%|███████▋  | 88647/115311 [00:04<00:00, 27581.59it/s]
# Matching predictions to ground truth, class 3/20.:  79%|███████▉  | 91461/115311 [00:04<00:00, 27745.90it/s]
# Matching predictions to ground truth, class 3/20.:  82%|████████▏ | 94286/115311 [00:04<00:00, 27893.51it/s]
# Matching predictions to ground truth, class 3/20.:  84%|████████▍ | 97087/115311 [00:04<00:00, 27926.47it/s]
# Matching predictions to ground truth, class 3/20.:  87%|████████▋ | 99882/115311 [00:04<00:00, 27916.05it/s]
# Matching predictions to ground truth, class 3/20.:  89%|████████▉ | 102746/115311 [00:04<00:00, 28128.58it/s]
# Matching predictions to ground truth, class 3/20.:  92%|█████████▏| 105667/115311 [00:05<00:00, 28443.26it/s]
# Matching predictions to ground truth, class 3/20.:  94%|█████████▍| 108545/115311 [00:05<00:00, 28535.16it/s]
# Matching predictions to ground truth, class 3/20.:  97%|█████████▋| 111433/115311 [00:05<00:00, 28637.04it/s]
# Matching predictions to ground truth, class 3/20.:  99%|█████████▉| 114346/115311 [00:05<00:00, 28781.25it/s]
# Matching predictions to ground truth, class 3/20.: 100%|██████████| 115311/115311 [00:05<00:00, 21304.60it/s]
#   0%|          | 0/43380 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 4/20.:   0%|          | 0/43380 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 4/20.:   2%|▏         | 963/43380 [00:00<00:04, 9620.81it/s]
# Matching predictions to ground truth, class 4/20.:   5%|▍         | 2021/43380 [00:00<00:04, 9889.51it/s]
# Matching predictions to ground truth, class 4/20.:   7%|▋         | 3111/43380 [00:00<00:03, 10171.67it/s]
# Matching predictions to ground truth, class 4/20.:  10%|▉         | 4243/43380 [00:00<00:03, 10489.71it/s]
# Matching predictions to ground truth, class 4/20.:  13%|█▎        | 5424/43380 [00:00<00:03, 10852.35it/s]
# Matching predictions to ground truth, class 4/20.:  15%|█▌        | 6700/43380 [00:00<00:03, 11361.58it/s]
# Matching predictions to ground truth, class 4/20.:  18%|█▊        | 8004/43380 [00:00<00:02, 11816.93it/s]
# Matching predictions to ground truth, class 4/20.:  22%|██▏       | 9372/43380 [00:00<00:02, 12316.80it/s]
# Matching predictions to ground truth, class 4/20.:  25%|██▌       | 10896/43380 [00:00<00:02, 13068.56it/s]
# Matching predictions to ground truth, class 4/20.:  29%|██▉       | 12543/43380 [00:01<00:02, 13929.95it/s]
# Matching predictions to ground truth, class 4/20.:  33%|███▎      | 14336/43380 [00:01<00:01, 14928.68it/s]
# Matching predictions to ground truth, class 4/20.:  37%|███▋      | 16235/43380 [00:01<00:01, 15951.77it/s]
# Matching predictions to ground truth, class 4/20.:  42%|████▏     | 18213/43380 [00:01<00:01, 16930.90it/s]
# Matching predictions to ground truth, class 4/20.:  47%|████▋     | 20336/43380 [00:01<00:01, 18024.99it/s]
# Matching predictions to ground truth, class 4/20.:  52%|█████▏    | 22550/43380 [00:01<00:01, 19087.58it/s]
# Matching predictions to ground truth, class 4/20.:  57%|█████▋    | 24820/43380 [00:01<00:00, 20043.60it/s]
# Matching predictions to ground truth, class 4/20.:  63%|██████▎   | 27240/43380 [00:01<00:00, 21130.85it/s]
# Matching predictions to ground truth, class 4/20.:  69%|██████▊   | 29737/43380 [00:01<00:00, 22146.74it/s]
# Matching predictions to ground truth, class 4/20.:  75%|███████▍  | 32356/43380 [00:01<00:00, 23222.17it/s]
# Matching predictions to ground truth, class 4/20.:  81%|████████  | 34925/43380 [00:02<00:00, 23911.16it/s]
# Matching predictions to ground truth, class 4/20.:  87%|████████▋ | 37535/43380 [00:02<00:00, 24521.27it/s]
# Matching predictions to ground truth, class 4/20.:  93%|█████████▎| 40211/43380 [00:02<00:00, 25151.18it/s]
# Matching predictions to ground truth, class 4/20.:  99%|█████████▉| 42977/43380 [00:02<00:00, 25854.09it/s]
# Matching predictions to ground truth, class 4/20.: 100%|██████████| 43380/43380 [00:02<00:00, 18727.03it/s]
#   0%|          | 0/119520 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 5/20.:   0%|          | 0/119520 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 5/20.:   1%|          | 1307/119520 [00:00<00:09, 13067.08it/s]
# Matching predictions to ground truth, class 5/20.:   2%|▏         | 2976/119520 [00:00<00:08, 13976.94it/s]
# Matching predictions to ground truth, class 5/20.:   4%|▍         | 4779/119520 [00:00<00:07, 14986.55it/s]
# Matching predictions to ground truth, class 5/20.:  62%|██████▏   | 73964/119520 [00:03<00:01, 25693.49it/s]
# Matching predictions to ground truth, class 5/20.:  64%|██████▍   | 76700/119520 [00:03<00:01, 26166.10it/s]
# Matching predictions to ground truth, class 5/20.:  66%|██████▋   | 79334/119520 [00:03<00:01, 26216.54it/s]
# Matching predictions to ground truth, class 5/20.:  69%|██████▊   | 82060/119520 [00:03<00:01, 26519.81it/s]
# Matching predictions to ground truth, class 5/20.:  71%|███████   | 84732/119520 [00:03<00:01, 26578.63it/s]
# Matching predictions to ground truth, class 5/20.:  73%|███████▎  | 87429/119520 [00:03<00:01, 26693.43it/s]
# Matching predictions to ground truth, class 5/20.:  75%|███████▌  | 90135/119520 [00:03<00:01, 26801.74it/s]
# Matching predictions to ground truth, class 5/20.:  78%|███████▊  | 92850/119520 [00:04<00:00, 26902.77it/s]
# Matching predictions to ground truth, class 5/20.:  80%|████████  | 95649/119520 [00:04<00:00, 27212.76it/s]
# Matching predictions to ground truth, class 5/20.:  82%|████████▏ | 98373/119520 [00:04<00:00, 26877.52it/s]
# Matching predictions to ground truth, class 5/20.:  85%|████████▍ | 101247/119520 [00:04<00:00, 27403.15it/s]
# Matching predictions to ground truth, class 5/20.:  87%|████████▋ | 104103/119520 [00:04<00:00, 27739.06it/s]
# Matching predictions to ground truth, class 5/20.:  89%|████████▉ | 106898/119520 [00:04<00:00, 27801.36it/s]
# Matching predictions to ground truth, class 5/20.:  92%|█████████▏| 109815/119520 [00:04<00:00, 28191.87it/s]
# Matching predictions to ground truth, class 5/20.:  94%|█████████▍| 112638/119520 [00:04<00:00, 27893.95it/s]
# Matching predictions to ground truth, class 5/20.:  97%|█████████▋| 115431/119520 [00:04<00:00, 27864.58it/s]
# Matching predictions to ground truth, class 5/20.:  99%|█████████▉| 118220/119520 [00:04<00:00, 27654.49it/s]
# Matching predictions to ground truth, class 5/20.: 100%|██████████| 119520/119520 [00:04<00:00, 23985.18it/s]
#   0%|          | 0/11498 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 6/20.:   0%|          | 0/11498 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 6/20.:  10%|█         | 1165/11498 [00:00<00:00, 11642.57it/s]
# Matching predictions to ground truth, class 6/20.:  20%|██        | 2306/11498 [00:00<00:00, 11568.19it/s]
# Matching predictions to ground truth, class 6/20.:  31%|███▏      | 3619/11498 [00:00<00:00, 11995.02it/s]
# Matching predictions to ground truth, class 6/20.:  44%|████▍     | 5033/11498 [00:00<00:00, 12564.66it/s]
# Matching predictions to ground truth, class 6/20.:  57%|█████▋    | 6552/11498 [00:00<00:00, 13251.04it/s]
# Matching predictions to ground truth, class 6/20.:  71%|███████   | 8135/11498 [00:00<00:00, 13928.85it/s]
# Matching predictions to ground truth, class 6/20.:  86%|████████▌ | 9856/11498 [00:00<00:00, 14769.78it/s]
# Matching predictions to ground truth, class 6/20.: 100%|██████████| 11498/11498 [00:00<00:00, 14555.87it/s]
#   0%|          | 0/84214 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 7/20.:   0%|          | 0/84214 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 7/20.:   1%|          | 828/84214 [00:00<00:10, 8275.23it/s]
# Matching predictions to ground truth, class 7/20.:   2%|▏         | 1722/84214 [00:00<00:09, 8462.18it/s]
# Matching predictions to ground truth, class 7/20.:   3%|▎         | 2658/84214 [00:00<00:09, 8710.72it/s]
# Matching predictions to ground truth, class 7/20.:   4%|▍         | 3671/84214 [00:00<00:08, 9092.53it/s]
# Matching predictions to ground truth, class 7/20.:   6%|▌         | 4670/84214 [00:00<00:08, 9343.29it/s]
# Matching predictions to ground truth, class 7/20.:   7%|▋         | 5693/84214 [00:00<00:08, 9591.41it/s]
# Matching predictions to ground truth, class 7/20.:   8%|▊         | 6689/84214 [00:00<00:07, 9698.50it/s]
# Matching predictions to ground truth, class 7/20.:   9%|▉         | 7724/84214 [00:00<00:07, 9882.51it/s]
# Matching predictions to ground truth, class 7/20.:  10%|█         | 8756/84214 [00:00<00:07, 10007.02it/s]
# Matching predictions to ground truth, class 7/20.:  12%|█▏        | 9818/84214 [00:01<00:07, 10182.31it/s]
# Matching predictions to ground truth, class 7/20.:  13%|█▎        | 10867/84214 [00:01<00:07, 10271.95it/s]
# Matching predictions to ground truth, class 7/20.:  14%|█▍        | 11901/84214 [00:01<00:07, 10292.01it/s]
# Matching predictions to ground truth, class 7/20.:  15%|█▌        | 12976/84214 [00:01<00:06, 10422.15it/s]
# Matching predictions to ground truth, class 7/20.:  17%|█▋        | 14090/84214 [00:01<00:06, 10623.70it/s]
# Matching predictions to ground truth, class 7/20.:  18%|█▊        | 15149/84214 [00:01<00:06, 10103.37it/s]
# Matching predictions to ground truth, class 7/20.:  19%|█▉        | 16163/84214 [00:01<00:06, 9934.86it/s]
# Matching predictions to ground truth, class 7/20.:  20%|██        | 17160/84214 [00:01<00:06, 9781.86it/s]
# Matching predictions to ground truth, class 7/20.:  22%|██▏       | 18257/84214 [00:01<00:06, 10110.16it/s]
# Matching predictions to ground truth, class 7/20.:  23%|██▎       | 19389/84214 [00:01<00:06, 10443.37it/s]
# Matching predictions to ground truth, class 7/20.:  24%|██▍       | 20498/84214 [00:02<00:05, 10629.03it/s]
# Matching predictions to ground truth, class 7/20.:  26%|██▌       | 21566/84214 [00:02<00:05, 10583.61it/s]
# Matching predictions to ground truth, class 7/20.:  27%|██▋       | 22781/84214 [00:02<00:05, 11007.91it/s]
# Matching predictions to ground truth, class 7/20.:  28%|██▊       | 24000/84214 [00:02<00:05, 11334.72it/s]
# Matching predictions to ground truth, class 7/20.:  30%|██▉       | 25186/84214 [00:02<00:05, 11486.17it/s]
# Matching predictions to ground truth, class 7/20.:  31%|███▏      | 26433/84214 [00:02<00:04, 11761.02it/s]
# Matching predictions to ground truth, class 7/20.:  33%|███▎      | 27653/84214 [00:02<00:04, 11888.88it/s]
# Matching predictions to ground truth, class 7/20.:  34%|███▍      | 28889/84214 [00:02<00:04, 12025.91it/s]
# Matching predictions to ground truth, class 7/20.:  36%|███▌      | 30108/84214 [00:02<00:04, 12070.93it/s]
# Matching predictions to ground truth, class 7/20.:  37%|███▋      | 31385/84214 [00:02<00:04, 12268.88it/s]
# Matching predictions to ground truth, class 7/20.:  39%|███▉      | 32729/84214 [00:03<00:04, 12594.31it/s]
# Matching predictions to ground truth, class 7/20.:  41%|████      | 34179/84214 [00:03<00:03, 13111.25it/s]
# Matching predictions to ground truth, class 7/20.:  42%|████▏     | 35618/84214 [00:03<00:03, 13470.12it/s]
# Matching predictions to ground truth, class 7/20.:  44%|████▍     | 37135/84214 [00:03<00:03, 13937.92it/s]
# Matching predictions to ground truth, class 7/20.:  46%|████▌     | 38653/84214 [00:03<00:03, 14287.49it/s]
# Matching predictions to ground truth, class 7/20.:  48%|████▊     | 40173/84214 [00:03<00:03, 14545.85it/s]
# Matching predictions to ground truth, class 7/20.:  49%|████▉     | 41636/84214 [00:03<00:02, 14395.40it/s]
# Matching predictions to ground truth, class 7/20.:  51%|█████▏    | 43222/84214 [00:03<00:02, 14802.26it/s]
# Matching predictions to ground truth, class 7/20.:  53%|█████▎    | 44745/84214 [00:03<00:02, 14924.75it/s]
# Matching predictions to ground truth, class 7/20.:  55%|█████▍    | 46243/84214 [00:03<00:02, 14237.48it/s]
# Matching predictions to ground truth, class 7/20.:  57%|█████▋    | 47797/84214 [00:04<00:02, 14603.88it/s]
# Matching predictions to ground truth, class 7/20.:  59%|█████▊    | 49425/84214 [00:04<00:02, 15065.75it/s]
# Matching predictions to ground truth, class 7/20.:  61%|██████    | 51046/84214 [00:04<00:02, 15389.47it/s]
# Matching predictions to ground truth, class 7/20.:  63%|██████▎   | 52714/84214 [00:04<00:01, 15750.34it/s]
# Matching predictions to ground truth, class 7/20.:  65%|██████▍   | 54477/84214 [00:04<00:01, 16269.97it/s]
# Matching predictions to ground truth, class 7/20.:  67%|██████▋   | 56200/84214 [00:04<00:01, 16545.40it/s]
# Matching predictions to ground truth, class 7/20.:  69%|██████▊   | 57863/84214 [00:04<00:01, 16178.91it/s]
# Matching predictions to ground truth, class 7/20.:  71%|███████   | 59650/84214 [00:04<00:01, 16651.40it/s]
# Matching predictions to ground truth, class 7/20.:  73%|███████▎  | 61324/84214 [00:04<00:01, 16407.92it/s]
# Matching predictions to ground truth, class 7/20.:  75%|███████▍  | 63126/84214 [00:04<00:01, 16859.46it/s]
# Matching predictions to ground truth, class 7/20.:  77%|███████▋  | 64836/84214 [00:05<00:01, 16929.82it/s]
# Matching predictions to ground truth, class 7/20.:  79%|███████▉  | 66535/84214 [00:05<00:01, 16853.96it/s]
# Matching predictions to ground truth, class 7/20.:  81%|████████  | 68243/84214 [00:05<00:00, 16919.07it/s]
# Matching predictions to ground truth, class 7/20.:  83%|████████▎ | 69965/84214 [00:05<00:00, 17005.97it/s]
# Matching predictions to ground truth, class 7/20.:  85%|████████▌ | 71668/84214 [00:05<00:00, 16948.06it/s]
# Matching predictions to ground truth, class 7/20.:  87%|████████▋ | 73365/84214 [00:05<00:00, 16623.20it/s]
# Matching predictions to ground truth, class 7/20.:  89%|████████▉ | 75109/84214 [00:05<00:00, 16855.86it/s]
# Matching predictions to ground truth, class 7/20.:  91%|█████████▏| 76883/84214 [00:05<00:00, 17107.86it/s]
# Matching predictions to ground truth, class 7/20.:  93%|█████████▎| 78719/84214 [00:05<00:00, 17463.81it/s]
# Matching predictions to ground truth, class 7/20.:  96%|█████████▌| 80632/84214 [00:05<00:00, 17931.79it/s]
# Matching predictions to ground truth, class 7/20.:  98%|█████████▊| 82596/84214 [00:06<00:00, 18406.73it/s]
# Matching predictions to ground truth, class 7/20.: 100%|██████████| 84214/84214 [00:06<00:00, 13664.67it/s]
#   0%|          | 0/14391 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 8/20.:   0%|          | 0/14391 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 8/20.:   6%|▌         | 897/14391 [00:00<00:01, 8963.00it/s]
# Matching predictions to ground truth, class 8/20.:  14%|█▍        | 2020/14391 [00:00<00:01, 9538.76it/s]
# Matching predictions to ground truth, class 8/20.:  22%|██▏       | 3123/14391 [00:00<00:01, 9940.11it/s]
# Matching predictions to ground truth, class 8/20.:  29%|██▉       | 4234/14391 [00:00<00:00, 10262.35it/s]
# Matching predictions to ground truth, class 8/20.:  37%|███▋      | 5371/14391 [00:00<00:00, 10569.74it/s]
# Matching predictions to ground truth, class 8/20.:  46%|████▌     | 6560/14391 [00:00<00:00, 10932.47it/s]
# Matching predictions to ground truth, class 8/20.:  54%|█████▍    | 7786/14391 [00:00<00:00, 11298.24it/s]
# Matching predictions to ground truth, class 8/20.:  63%|██████▎   | 9019/14391 [00:00<00:00, 11588.17it/s]
# Matching predictions to ground truth, class 8/20.:  71%|███████   | 10253/14391 [00:00<00:00, 11803.52it/s]
# Matching predictions to ground truth, class 8/20.:  80%|████████  | 11543/14391 [00:01<00:00, 12109.12it/s]
# Matching predictions to ground truth, class 8/20.:  89%|████████▉ | 12838/14391 [00:01<00:00, 12345.79it/s]
# Matching predictions to ground truth, class 8/20.:  98%|█████████▊| 14139/14391 [00:01<00:00, 12534.58it/s]
# Matching predictions to ground truth, class 8/20.: 100%|██████████| 14391/14391 [00:01<00:00, 11790.40it/s]
#   0%|          | 0/216458 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 9/20.:   0%|          | 0/216458 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 9/20.:   0%|          | 944/216458 [00:00<00:22, 9431.33it/s]
# Matching predictions to ground truth, class 9/20.:   1%|          | 2006/216458 [00:00<00:21, 9758.20it/s]
# Matching predictions to ground truth, class 9/20.:   1%|▏         | 3146/216458 [00:00<00:20, 10198.00it/s]
# Matching predictions to ground truth, class 9/20.:   2%|▏         | 4304/216458 [00:00<00:20, 10576.56it/s]
# Matching predictions to ground truth, class 9/20.:   3%|▎         | 5546/216458 [00:00<00:19, 11068.32it/s]
# Matching predictions to ground truth, class 9/20.:   3%|▎         | 6796/216458 [00:00<00:18, 11458.40it/s]
# Matching predictions to ground truth, class 16/20.:  83%|████████▎ | 538918/648789 [00:19<00:03, 31488.16it/s]
# Matching predictions to ground truth, class 16/20.:  84%|████████▎ | 542214/648789 [00:19<00:03, 31913.05it/s]
# Matching predictions to ground truth, class 16/20.:  84%|████████▍ | 545469/648789 [00:19<00:03, 32099.82it/s]
# Matching predictions to ground truth, class 16/20.:  85%|████████▍ | 548764/648789 [00:19<00:03, 32349.96it/s]
# Matching predictions to ground truth, class 16/20.:  85%|████████▌ | 552010/648789 [00:19<00:02, 32380.11it/s]
# Matching predictions to ground truth, class 16/20.:  86%|████████▌ | 555252/648789 [00:19<00:02, 32110.81it/s]
# Matching predictions to ground truth, class 16/20.:  86%|████████▌ | 558467/648789 [00:19<00:02, 31862.66it/s]
# Matching predictions to ground truth, class 16/20.:  87%|████████▋ | 561677/648789 [00:20<00:02, 31930.80it/s]
# Matching predictions to ground truth, class 16/20.:  87%|████████▋ | 564872/648789 [00:20<00:02, 31904.97it/s]
# Matching predictions to ground truth, class 16/20.:  88%|████████▊ | 568064/648789 [00:20<00:02, 31878.40it/s]
# Matching predictions to ground truth, class 16/20.:  88%|████████▊ | 571320/648789 [00:20<00:02, 32079.31it/s]
# Matching predictions to ground truth, class 16/20.:  89%|████████▊ | 574599/648789 [00:20<00:02, 32286.49it/s]
# Matching predictions to ground truth, class 16/20.:  89%|████████▉ | 577829/648789 [00:20<00:02, 32287.11it/s]
# Matching predictions to ground truth, class 16/20.:  90%|████████▉ | 581059/648789 [00:20<00:02, 31743.12it/s]
# Matching predictions to ground truth, class 16/20.:  90%|█████████ | 584349/648789 [00:20<00:02, 32078.27it/s]
# Matching predictions to ground truth, class 16/20.:  91%|█████████ | 587561/648789 [00:20<00:01, 32089.69it/s]
# Matching predictions to ground truth, class 16/20.:  91%|█████████ | 590817/648789 [00:20<00:01, 32227.78it/s]
# Matching predictions to ground truth, class 16/20.:  92%|█████████▏| 594084/648789 [00:21<00:01, 32356.86it/s]
# Matching predictions to ground truth, class 16/20.:  92%|█████████▏| 597321/648789 [00:21<00:01, 26649.09it/s]
# Matching predictions to ground truth, class 16/20.:  93%|█████████▎| 600154/648789 [00:21<00:01, 26671.71it/s]
# Matching predictions to ground truth, class 16/20.:  93%|█████████▎| 603016/648789 [00:21<00:01, 27227.75it/s]
# Matching predictions to ground truth, class 16/20.:  93%|█████████▎| 606125/648789 [00:21<00:01, 28280.39it/s]
# Matching predictions to ground truth, class 16/20.:  94%|█████████▍| 609246/648789 [00:21<00:01, 29099.49it/s]
# Matching predictions to ground truth, class 16/20.:  94%|█████████▍| 612423/648789 [00:21<00:01, 29851.31it/s]
# Matching predictions to ground truth, class 16/20.:  95%|█████████▍| 615555/648789 [00:21<00:01, 30276.52it/s]
# Matching predictions to ground truth, class 16/20.:  95%|█████████▌| 618709/648789 [00:21<00:00, 30643.37it/s]
# Matching predictions to ground truth, class 16/20.:  96%|█████████▌| 621848/648789 [00:22<00:00, 30862.89it/s]
# Matching predictions to ground truth, class 16/20.:  96%|█████████▋| 624977/648789 [00:22<00:00, 30988.73it/s]
# Matching predictions to ground truth, class 16/20.:  97%|█████████▋| 628168/648789 [00:22<00:00, 31258.15it/s]
# Matching predictions to ground truth, class 16/20.:  97%|█████████▋| 631321/648789 [00:22<00:00, 31337.44it/s]
# Matching predictions to ground truth, class 16/20.:  98%|█████████▊| 634461/648789 [00:22<00:00, 31280.16it/s]
# Matching predictions to ground truth, class 16/20.:  98%|█████████▊| 637657/648789 [00:22<00:00, 31479.91it/s]
# Matching predictions to ground truth, class 16/20.:  99%|█████████▉| 640854/648789 [00:22<00:00, 31622.97it/s]
# Matching predictions to ground truth, class 16/20.:  99%|█████████▉| 644054/648789 [00:22<00:00, 31733.03it/s]
# Matching predictions to ground truth, class 16/20.: 100%|█████████▉| 647262/648789 [00:22<00:00, 31836.00it/s]
# Matching predictions to ground truth, class 16/20.: 100%|██████████| 648789/648789 [00:22<00:00, 28367.59it/s]
#   0%|          | 0/20982 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 17/20.:   0%|          | 0/20982 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 17/20.:   5%|▌         | 1057/20982 [00:00<00:01, 10561.68it/s]
# Matching predictions to ground truth, class 17/20.:  11%|█▏        | 2410/20982 [00:00<00:01, 11305.52it/s]
# Matching predictions to ground truth, class 17/20.:  19%|█▊        | 3919/20982 [00:00<00:01, 12224.01it/s]
# Matching predictions to ground truth, class 17/20.:  27%|██▋       | 5573/20982 [00:00<00:01, 13260.62it/s]
# Matching predictions to ground truth, class 17/20.:  35%|███▌      | 7382/20982 [00:00<00:00, 14414.78it/s]
# Matching predictions to ground truth, class 17/20.:  44%|████▍     | 9302/20982 [00:00<00:00, 15579.44it/s]
# Matching predictions to ground truth, class 17/20.:  55%|█████▍    | 11438/20982 [00:00<00:00, 16955.00it/s]
# Matching predictions to ground truth, class 17/20.:  66%|██████▌   | 13749/20982 [00:00<00:00, 18426.26it/s]
# Matching predictions to ground truth, class 17/20.:  77%|███████▋  | 16083/20982 [00:00<00:00, 19667.98it/s]
# Matching predictions to ground truth, class 17/20.:  88%|████████▊ | 18561/20982 [00:01<00:00, 20965.12it/s]
# Matching predictions to ground truth, class 17/20.: 100%|██████████| 20982/20982 [00:01<00:00, 19186.77it/s]
#   0%|          | 0/5196 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 18/20.:   0%|          | 0/5196 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 18/20.:  18%|█▊        | 929/5196 [00:00<00:00, 9253.45it/s]
# Matching predictions to ground truth, class 18/20.:  42%|████▏     | 2182/5196 [00:00<00:00, 10039.89it/s]
# Matching predictions to ground truth, class 18/20.:  70%|██████▉   | 3628/5196 [00:00<00:00, 11050.74it/s]
# Matching predictions to ground truth, class 18/20.:  99%|█████████▉| 5162/5196 [00:00<00:00, 12055.17it/s]
# Matching predictions to ground truth, class 18/20.: 100%|██████████| 5196/5196 [00:00<00:00, 12833.92it/s]
#   0%|          | 0/10762 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 19/20.:   0%|          | 0/10762 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 19/20.:   9%|▉         | 963/10762 [00:00<00:01, 9628.75it/s]
# Matching predictions to ground truth, class 19/20.:  19%|█▊        | 2006/10762 [00:00<00:00, 9853.36it/s]
# Matching predictions to ground truth, class 19/20.:  28%|██▊       | 3066/10762 [00:00<00:00, 10065.83it/s]
# Matching predictions to ground truth, class 19/20.:  39%|███▊      | 4169/10762 [00:00<00:00, 10334.53it/s]
# Matching predictions to ground truth, class 19/20.:  49%|████▉     | 5303/10762 [00:00<00:00, 10614.04it/s]
# Matching predictions to ground truth, class 19/20.:  60%|██████    | 6459/10762 [00:00<00:00, 10878.10it/s]
# Matching predictions to ground truth, class 19/20.:  71%|███████▏  | 7692/10762 [00:00<00:00, 11275.91it/s]
# Matching predictions to ground truth, class 19/20.:  83%|████████▎ | 8922/10762 [00:00<00:00, 11563.98it/s]
# Matching predictions to ground truth, class 19/20.:  94%|█████████▎| 10065/10762 [00:00<00:00, 11519.11it/s]
# Matching predictions to ground truth, class 19/20.: 100%|██████████| 10762/10762 [00:00<00:00, 11292.47it/s]
#   0%|          | 0/36906 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 20/20.:   0%|          | 0/36906 [00:00<?, ?it/s]
# Matching predictions to ground truth, class 20/20.:   3%|▎         | 1108/36906 [00:00<00:03, 11077.77it/s]
# Matching predictions to ground truth, class 20/20.:   7%|▋         | 2518/36906 [00:00<00:02, 11836.89it/s]
# Matching predictions to ground truth, class 20/20.:  11%|█         | 4046/36906 [00:00<00:02, 12691.74it/s]
# Matching predictions to ground truth, class 20/20.:  15%|█▌        | 5589/36906 [00:00<00:02, 13401.59it/s]
# Matching predictions to ground truth, class 20/20.:  18%|█▊        | 6793/36906 [00:00<00:02, 12960.72it/s]
# Matching predictions to ground truth, class 20/20.:  23%|██▎       | 8368/36906 [00:00<00:02, 13686.79it/s]
# Matching predictions to ground truth, class 20/20.:  28%|██▊       | 10176/36906 [00:00<00:01, 14760.00it/s]
# Matching predictions to ground truth, class 20/20.:  32%|███▏      | 11916/36906 [00:00<00:01, 15461.78it/s]
# Matching predictions to ground truth, class 20/20.:  37%|███▋      | 13761/36906 [00:00<00:01, 16248.97it/s]
# Matching predictions to ground truth, class 20/20.:  42%|████▏     | 15676/36906 [00:01<00:01, 17018.60it/s]
# Matching predictions to ground truth, class 20/20.:  48%|████▊     | 17643/36906 [00:01<00:01, 17735.54it/s]
# Matching predictions to ground truth, class 20/20.:  53%|█████▎    | 19625/36906 [00:01<00:00, 18311.68it/s]
# Matching predictions to ground truth, class 20/20.:  58%|█████▊    | 21583/36906 [00:01<00:00, 18674.37it/s]
# Matching predictions to ground truth, class 20/20.:  64%|██████▍   | 23596/36906 [00:01<00:00, 19087.54it/s]
# Matching predictions to ground truth, class 20/20.:  69%|██████▉   | 25647/36906 [00:01<00:00, 19491.82it/s]
# Matching predictions to ground truth, class 20/20.:  75%|███████▌  | 27695/36906 [00:01<00:00, 19777.67it/s]
# Matching predictions to ground truth, class 20/20.:  81%|████████  | 29835/36906 [00:01<00:00, 20234.07it/s]
# Matching predictions to ground truth, class 20/20.:  87%|████████▋ | 31928/36906 [00:01<00:00, 20437.79it/s]
# Matching predictions to ground truth, class 20/20.:  92%|█████████▏| 34097/36906 [00:01<00:00, 20796.86it/s]
# Matching predictions to ground truth, class 20/20.:  99%|█████████▊| 36362/36906 [00:02<00:00, 21319.75it/s]
# Matching predictions to ground truth, class 20/20.: 100%|██████████| 36906/36906 [00:02<00:00, 18213.95it/s]Computing precisions and recalls, class 1/20
# Computing precisions and recalls, class 2/20
# Computing precisions and recalls, class 3/20
# Computing precisions and recalls, class 4/20
# Computing precisions and recalls, class 5/20
# Computing precisions and recalls, class 6/20
# Computing precisions and recalls, class 7/20
# Computing precisions and recalls, class 8/20
# Computing precisions and recalls, class 9/20
# Computing precisions and recalls, class 10/20
# Computing precisions and recalls, class 11/20
# Computing precisions and recalls, class 12/20
# Computing precisions and recalls, class 13/20
# Computing precisions and recalls, class 14/20
# Computing precisions and recalls, class 15/20
# Computing precisions and recalls, class 16/20
# Computing precisions and recalls, class 17/20
# Computing precisions and recalls, class 18/20
# Computing precisions and recalls, class 19/20
# Computing precisions and recalls, class 20/20
# Computing average precision, class 1/20
# Computing average precision, class 2/20
# Computing average precision, class 3/20
# Computing average precision, class 4/20
# Computing average precision, class 5/20
# Computing average precision, class 6/20
# Computing average precision, class 7/20
# Computing average precision, class 8/20
# Computing average precision, class 9/20
# Computing average precision, class 10/20
# Computing average precision, class 11/20
# Computing average precision, class 12/20
# Computing average precision, class 13/20
# Computing average precision, class 14/20
# Computing average precision, class 15/20
# Computing average precision, class 16/20
# Computing average precision, class 17/20
# Computing average precision, class 18/20
# Computing average precision, class 19/20
# Computing average precision, class 20/20

# %%
for i in range(1, len(average_precisions)):
    print("{:<14}{:<6}{}".format(class_names[i], 'AP', round(average_precisions[i], 3)))
print()
print("{:<14}{:<6}{}".format('','mAP', round(mean_average_precision, 3)))
# Out:
# aeroplane     AP    0.687
# bicycle       AP    0.754
# bird          AP    0.583
# boat          AP    0.523
# bottle        AP    0.232
# bus           AP    0.777
# car           AP    0.733
# cat           AP    0.819
# chair         AP    0.401
# cow           AP    0.613
# diningtable   AP    0.681
# dog           AP    0.741
# horse         AP    0.779
# motorbike     AP    0.772
# person        AP    0.621
# pottedplant   AP    0.378
# sheep         AP    0.648
# sofa          AP    0.658
# train         AP    0.777
# tvmonitor     AP    0.621
#
#               mAP   0.64

# %%
m = max((num_classes + 1) // 2, 2)
n = 2

fig, cells = plt.subplots(m, n, figsize=(n*8,m*8))
for i in range(m):
    for j in range(n):
        if n*i+j+1 > num_classes: break
        cells[i, j].plot(recalls[n*i+j+1], precisions[n*i+j+1], color='blue', linewidth=1.0)
        cells[i, j].set_xlabel('recall', fontsize=14)
        cells[i, j].set_ylabel('precision', fontsize=14)
        cells[i, j].grid(True)
        cells[i, j].set_xticks(np.linspace(0,1,11))
        cells[i, j].set_yticks(np.linspace(0,1,11))
        cells[i, j].set_title("{}, AP: {:.3f}".format(class_names[n*i+j+1], average_precisions[n*i+j+1]), fontsize=16)

# %% [markdown]
# ### Predict

# %%
# 1: Set the generator for the predictions.

predict_generator = val_dataset.generate(batch_size=1,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# %%
# Generate batch_items
batch_images, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 0 # Which batch item to look at

#print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))


# 3: Make predictions.
y_pred = model.predict(batch_images)

# %%
# 4: Decode labels
reload(detector_help)
y_pred_decoded = decode_detections(y_pred,
                  priors,variances,
                  img_height = input_H,
                  img_width = input_W,
                  confidence_thresh = 0.5,
                  iou_threshold = 0.45)
# y_pred_decoded = detector_help.post_process(y_pred, 
#                                             priors,
#                                             num_classes,
#                                             input_H, 
#                                             input_W,
#                                             score_thresh = 0.5,
#                                             iou_thresh = 0.4)
y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# %%
# 5: Draw 
colors = plt.cm.hsv(np.linspace(0, 1, num_classes+1)).tolist()
draw_detection(batch_original_images[i],y_pred_decoded_inv[i],class_names,
               show = True, draw_score = True,use_cm = True,color = colors, size = 'medium')
draw_detection(batch_original_images[i],batch_original_labels[i],class_names, size = 'medium')

# %% [markdown]
# ### Image Demo

# %%
img_file = "data/dog3.jpg"
img = cv2.imread(img_file)
img = cv2.resize(img,(224,224))
x = cv2.resize(img, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
x = np.array(x,dtype='float')
x = x / 255
y_pred = model.predict(np.expand_dims(x,0))
y_pred = post_process(y_pred,priors,num_classes,input_H,input_W)
print(y_pred)
draw_detection(img,y_pred[0],class_names)

# %% [markdown]
# ### Video detection demo

# %%
video_file = "data/cat_video.mp4"
result_file = "res.avi"
cap= cv2.VideoCapture(video_file)
fps = cap.get(cv2.CAP_PROP_FPS)
size = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
frames = (int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print('Input Video Size:',size,' Fps:',fps,' Frames:',frames)
writer = cv2.VideoWriter(result_file,cv2.VideoWriter_fourcc(*'MJPG'), fps, size)
success,frame = cap.read()
count = 1
while success:
    x = cv2.resize(frame,dsize=(input_H,input_W),interpolation=cv2.INTER_CUBIC)
    x = x / 255
    y_pred = model.predict(np.expand_dims(x,0))[0]
    y_pred [-4:] *= [*size,*size]
    draw_detection(frame, y_pred,class_names,font_scale = 1)
    writer.write(frame)
    cv2.waitKey(1)
    count += 1
    if count%50==0:
        print(y_pred)
        plt.imshow(frame)
        plt.show()
        print('.',end='')
    success,frame = cap.read()
print('done')
