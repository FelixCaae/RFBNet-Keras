# %%
import os
import copy
import random
from matplotlib import pyplot as plt
import numpy as np
#From keras
import keras
from keras.models import load_model
# from keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
from keras import optimizers
from keras.utils import multi_gpu_model
from keras import backend as K
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TerminateOnNaN, CSVLogger
# From ssd_keras
from data_generator.object_detection_2d_data_generator import DataGenerator
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_geometric_ops import Resize
from data_generator.object_detection_2d_photometric_ops import ConvertTo3Channels
from data_generator.data_augmentation_chain_original_ssd import SSDDataAugmentation
from data_generator.object_detection_2d_misc_utils import apply_inverse_transforms
from ssd_encoder_decoder.ssd_input_encoder import SSDInputEncoder
import ssd_encoder_decoder.ssd_output_decoder
from ssd_encoder_decoder.ssd_output_decoder import decode_detections
from SSD_loss import SSDLoss
from eval_utils.average_precision_evaluator import Evaluator
from importlib import reload
#import cv2
from data_augment import LabelEncoder
from detector_help import process_y,post_process,prior_box
import detection_nets,classification_nets
import tensorflow as tf
from matplotlib import pyplot as plt
from drawing import *
from detection_nets import load_mobilenetv2
# %matplotlib inline

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import tensorflow as tf
import keras.backend as K


def get_flops():
    run_meta = tf.RunMetadata()
    opts = tf.profiler.ProfileOptionBuilder.float_operation()

    # We use the Keras session graph in the call to the profiler.
    flops = tf.profiler.profile(graph=K.get_session().graph,
                                run_meta=run_meta, cmd='op', options=opts)

    return flops.total_float_ops  # Prints the "flops" of the model.

# %% [markdown]
# ### Set model config

# %%
input_H = 300
input_W = 300
input_C = 3
input_shape = (input_H, input_W, input_C)
model_name = "rfblite_mn2_300_b"
root_path = "/home/cai/dataset/VOCdevkit"
aspect_ratios = [[2,3],
                 [2,3],
                 [2,3],
                 [2,3],
                 [2],
                 [2]]
prior_config =  [2 + len(ar) * 2 for ar in aspect_ratios]  # number of boxes per feature map location
source_layers = ["block_12_expand"] #["block_6_expand","block_12_expand"]
#Model config
model_config = [[32,4,128,True],
               [48,6,128,False],
               [64,6,256,True],
               [80,6,128,False]]
mean_color = [123, 117, 104] 
swap_channels = [2, 1, 0] # The color channel order in the original SSD is BGR, so we'll have the model reverse the color channel order of the input images.
num_classes = 20 # Number of positive classes, e.g. 20 for Pascal VOC, 80 for MS COCO
variances = [0.1, 0.1, 0.2, 0.2]
scale = [0.1, 0.2, 0.37, 0.54, 0.71, 0.88, 1.05]

# %%
reload(detection_nets)
##Load basenet first
K.clear_session()
model = detection_nets.build_tiny_dsod((300,300,3),
              num_classes,
              prior_config,
              model_config,
              return_predictor = True)

model.summary()                       #Comment this line if you don`t want to show summary every time you build your model
# print(get_flops())
model = detection_nets.preprocess(input_shape,model,mean_color,swap_channels)
# model = multi_gpu_model(model,gpus=gpus) #Comment it if don`t use multi_gpu 

#Don`t tune learning rate here because we will use a lr scheduler in callbacks
#Orignal paper used SGD but according to the author of ssd_keras, use adam is better 
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3,alpha=1.0)
model.compile(adam,
              loss=ssd_loss.loss,
              metrics = [ssd_loss.class_loss,ssd_loss.loc_loss]
              )
print(model_name,'has been built ')
# Out:
# [[38 38]
#  [19 19]
#  [10 10]
#  [ 5  5]
#  [ 3  3]
#  [ 2  2]]
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 300, 300, 3)  0
# __________________________________________________________________________________________________
# stem (Sequential)               (None, 75, 75, 128)  17536       input_1[0][0]
# __________________________________________________________________________________________________
# sequential_6 (Sequential)       (None, 75, 75, 32)   4224        stem[1][0]
# __________________________________________________________________________________________________
# sequential_7 (Sequential)       (None, 75, 75, 32)   416         sequential_6[1][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 75, 75, 160)  0           stem[1][0]
#                                                                  sequential_7[1][0]
# __________________________________________________________________________________________________
# sequential_8 (Sequential)       (None, 75, 75, 32)   5248        concatenate_1[0][0]
# __________________________________________________________________________________________________
# sequential_9 (Sequential)       (None, 75, 75, 32)   416         sequential_8[1][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 75, 75, 192)  0           concatenate_1[0][0]
#                                                                  sequential_9[1][0]
# __________________________________________________________________________________________________
# sequential_10 (Sequential)      (None, 75, 75, 32)   6272        concatenate_2[0][0]
# __________________________________________________________________________________________________
# sequential_11 (Sequential)      (None, 75, 75, 32)   416         sequential_10[1][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 75, 75, 224)  0           concatenate_2[0][0]
#                                                                  sequential_11[1][0]
# __________________________________________________________________________________________________
# sequential_12 (Sequential)      (None, 75, 75, 32)   7296        concatenate_3[0][0]
# __________________________________________________________________________________________________
# sequential_13 (Sequential)      (None, 75, 75, 32)   416         sequential_12[1][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 75, 75, 256)  0           concatenate_3[0][0]
#                                                                  sequential_13[1][0]
# __________________________________________________________________________________________________
# sequential_14 (Sequential)      (None, 38, 38, 128)  33280       concatenate_4[0][0]
# __________________________________________________________________________________________________
# sequential_16 (Sequential)      (None, 38, 38, 48)   6336        sequential_14[1][0]
# __________________________________________________________________________________________________
# sequential_17 (Sequential)      (None, 38, 38, 48)   624         sequential_16[1][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 38, 38, 176)  0           sequential_14[1][0]
#                                                                  sequential_17[1][0]
# __________________________________________________________________________________________________
# sequential_18 (Sequential)      (None, 38, 38, 48)   8640        concatenate_5[0][0]
# __________________________________________________________________________________________________
# sequential_19 (Sequential)      (None, 38, 38, 48)   624         sequential_18[1][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 38, 38, 224)  0           concatenate_5[0][0]
#                                                                  sequential_19[1][0]
# __________________________________________________________________________________________________
# sequential_20 (Sequential)      (None, 38, 38, 48)   10944       concatenate_6[0][0]
# __________________________________________________________________________________________________
# sequential_21 (Sequential)      (None, 38, 38, 48)   624         sequential_20[1][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 38, 38, 272)  0           concatenate_6[0][0]
#                                                                  sequential_21[1][0]
# __________________________________________________________________________________________________
# sequential_22 (Sequential)      (None, 38, 38, 48)   13248       concatenate_7[0][0]
# __________________________________________________________________________________________________
# sequential_23 (Sequential)      (None, 38, 38, 48)   624         sequential_22[1][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 38, 38, 320)  0           concatenate_7[0][0]
#                                                                  sequential_23[1][0]
# __________________________________________________________________________________________________
# sequential_24 (Sequential)      (None, 38, 38, 48)   15552       concatenate_8[0][0]
# __________________________________________________________________________________________________
# sequential_25 (Sequential)      (None, 38, 38, 48)   624         sequential_24[1][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 38, 38, 368)  0           concatenate_8[0][0]
#                                                                  sequential_25[1][0]
# __________________________________________________________________________________________________
# sequential_26 (Sequential)      (None, 38, 38, 48)   17856       concatenate_9[0][0]
# __________________________________________________________________________________________________
# sequential_27 (Sequential)      (None, 38, 38, 48)   624         sequential_26[1][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 38, 38, 416)  0           concatenate_9[0][0]
#                                                                  sequential_27[1][0]
# __________________________________________________________________________________________________
# sequential_28 (Sequential)      (None, 38, 38, 128)  53760       concatenate_10[0][0]
# __________________________________________________________________________________________________
# sequential_30 (Sequential)      (None, 38, 38, 64)   8448        sequential_28[1][0]
# __________________________________________________________________________________________________
# sequential_31 (Sequential)      (None, 38, 38, 64)   832         sequential_30[1][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 38, 38, 192)  0           sequential_28[1][0]
#                                                                  sequential_31[1][0]
# __________________________________________________________________________________________________
# sequential_32 (Sequential)      (None, 38, 38, 64)   12544       concatenate_11[0][0]
# __________________________________________________________________________________________________
# sequential_33 (Sequential)      (None, 38, 38, 64)   832         sequential_32[1][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 38, 38, 256)  0           concatenate_11[0][0]
#                                                                  sequential_33[1][0]
# __________________________________________________________________________________________________
# sequential_34 (Sequential)      (None, 38, 38, 64)   16640       concatenate_12[0][0]
# __________________________________________________________________________________________________
# sequential_35 (Sequential)      (None, 38, 38, 64)   832         sequential_34[1][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 38, 38, 320)  0           concatenate_12[0][0]
#                                                                  sequential_35[1][0]
# __________________________________________________________________________________________________
# sequential_36 (Sequential)      (None, 38, 38, 64)   20736       concatenate_13[0][0]
# __________________________________________________________________________________________________
# sequential_37 (Sequential)      (None, 38, 38, 64)   832         sequential_36[1][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 38, 38, 384)  0           concatenate_13[0][0]
#                                                                  sequential_37[1][0]
# __________________________________________________________________________________________________
# sequential_38 (Sequential)      (None, 38, 38, 64)   24832       concatenate_14[0][0]
# __________________________________________________________________________________________________
# sequential_39 (Sequential)      (None, 38, 38, 64)   832         sequential_38[1][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 38, 38, 448)  0           concatenate_14[0][0]
#                                                                  sequential_39[1][0]
# __________________________________________________________________________________________________
# sequential_40 (Sequential)      (None, 38, 38, 64)   28928       concatenate_15[0][0]
# __________________________________________________________________________________________________
# sequential_41 (Sequential)      (None, 38, 38, 64)   832         sequential_40[1][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 38, 38, 512)  0           concatenate_15[0][0]
#                                                                  sequential_41[1][0]
# __________________________________________________________________________________________________
# sequential_42 (Sequential)      (None, 19, 19, 256)  132096      concatenate_16[0][0]
# __________________________________________________________________________________________________
# sequential_44 (Sequential)      (None, 19, 19, 80)   20800       sequential_42[1][0]
# __________________________________________________________________________________________________
# sequential_45 (Sequential)      (None, 19, 19, 80)   1040        sequential_44[1][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 19, 19, 336)  0           sequential_42[1][0]
#                                                                  sequential_45[1][0]
# __________________________________________________________________________________________________
# sequential_46 (Sequential)      (None, 19, 19, 80)   27200       concatenate_17[0][0]
# __________________________________________________________________________________________________
# sequential_47 (Sequential)      (None, 19, 19, 80)   1040        sequential_46[1][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 19, 19, 416)  0           concatenate_17[0][0]
#                                                                  sequential_47[1][0]
# __________________________________________________________________________________________________
# sequential_48 (Sequential)      (None, 19, 19, 80)   33600       concatenate_18[0][0]
# __________________________________________________________________________________________________
# sequential_49 (Sequential)      (None, 19, 19, 80)   1040        sequential_48[1][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 19, 19, 496)  0           concatenate_18[0][0]
#                                                                  sequential_49[1][0]
# __________________________________________________________________________________________________
# sequential_50 (Sequential)      (None, 19, 19, 80)   40000       concatenate_19[0][0]
# __________________________________________________________________________________________________
# sequential_51 (Sequential)      (None, 19, 19, 80)   1040        sequential_50[1][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 19, 19, 576)  0           concatenate_19[0][0]
#                                                                  sequential_51[1][0]
# __________________________________________________________________________________________________
# sequential_52 (Sequential)      (None, 19, 19, 80)   46400       concatenate_20[0][0]
# __________________________________________________________________________________________________
# sequential_53 (Sequential)      (None, 19, 19, 80)   1040        sequential_52[1][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 19, 19, 656)  0           concatenate_20[0][0]
#                                                                  sequential_53[1][0]
# __________________________________________________________________________________________________
# sequential_54 (Sequential)      (None, 19, 19, 80)   52800       concatenate_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 19, 19, 128)  0           sequential_28[1][0]
# __________________________________________________________________________________________________
# sequential_59 (Sequential)      (None, 38, 38, 64)   8448        sequential_28[1][0]
# __________________________________________________________________________________________________
# sequential_55 (Sequential)      (None, 19, 19, 80)   1040        sequential_54[1][0]
# __________________________________________________________________________________________________
# sequential_58 (Sequential)      (None, 19, 19, 64)   8448        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# sequential_60 (Sequential)      (None, 19, 19, 64)   832         sequential_59[1][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 19, 19, 736)  0           concatenate_21[0][0]
#                                                                  sequential_55[1][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 19, 19, 128)  0           sequential_58[1][0]
#                                                                  sequential_60[1][0]
# __________________________________________________________________________________________________
# sequential_56 (Sequential)      (None, 19, 19, 128)  94720       concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 19, 19, 256)  0           concatenate_24[0][0]
#                                                                  sequential_56[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 10, 10, 256)  0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# sequential_62 (Sequential)      (None, 19, 19, 64)   16640       concatenate_23[0][0]
# __________________________________________________________________________________________________
# sequential_61 (Sequential)      (None, 10, 10, 64)   16640       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# sequential_63 (Sequential)      (None, 10, 10, 64)   832         sequential_62[1][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 10, 10, 128)  0           sequential_61[1][0]
#                                                                  sequential_63[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 5, 5, 128)    0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# sequential_65 (Sequential)      (None, 10, 10, 64)   8448        concatenate_25[0][0]
# __________________________________________________________________________________________________
# sequential_64 (Sequential)      (None, 5, 5, 64)     8448        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# sequential_66 (Sequential)      (None, 5, 5, 64)     832         sequential_65[1][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 5, 5, 128)    0           sequential_64[1][0]
#                                                                  sequential_66[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 3, 3, 128)    0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# sequential_68 (Sequential)      (None, 5, 5, 64)     8448        concatenate_26[0][0]
# __________________________________________________________________________________________________
# sequential_67 (Sequential)      (None, 3, 3, 64)     8448        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# sequential_69 (Sequential)      (None, 3, 3, 64)     832         sequential_68[1][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 3, 3, 128)    0           sequential_67[1][0]
#                                                                  sequential_69[1][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 2, 2, 128)    0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# sequential_71 (Sequential)      (None, 3, 3, 64)     8448        concatenate_27[0][0]
# __________________________________________________________________________________________________
# sequential_70 (Sequential)      (None, 2, 2, 64)     8448        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# sequential_72 (Sequential)      (None, 2, 2, 64)     832         sequential_71[1][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 2, 2, 128)    0           sequential_70[1][0]
#                                                                  sequential_72[1][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 4, 4, 128)    0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# sequential_73 (Sequential)      (None, 4, 4, 128)    1664        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_1 (Cropping2D)       (None, 3, 3, 128)    0           sequential_73[1][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 3, 3, 128)    0           cropping2d_1[0][0]
#                                                                  concatenate_27[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 6, 6, 128)    0           add_1[0][0]
# __________________________________________________________________________________________________
# sequential_74 (Sequential)      (None, 6, 6, 128)    1664        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_2 (Cropping2D)       (None, 5, 5, 128)    0           sequential_74[1][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 5, 5, 128)    0           cropping2d_2[0][0]
#                                                                  concatenate_26[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 10, 10, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# sequential_75 (Sequential)      (None, 10, 10, 128)  1664        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 10, 10, 128)  0           sequential_75[1][0]
#                                                                  concatenate_25[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 20, 20, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# sequential_76 (Sequential)      (None, 20, 20, 128)  1664        up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# cropping2d_3 (Cropping2D)       (None, 19, 19, 128)  0           sequential_76[1][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 128)  0           cropping2d_3[0][0]
#                                                                  sequential_56[1][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 38, 38, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# sequential_77 (Sequential)      (None, 38, 38, 128)  1664        up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 38, 38, 128)  0           sequential_77[1][0]
#                                                                  sequential_28[1][0]
# __________________________________________________________________________________________________
# sequential_79 (Sequential)      (None, 38, 38, 126)  17784       add_5[0][0]
# __________________________________________________________________________________________________
# sequential_81 (Sequential)      (None, 19, 19, 126)  17784       add_4[0][0]
# __________________________________________________________________________________________________
# sequential_83 (Sequential)      (None, 10, 10, 126)  17784       add_3[0][0]
# __________________________________________________________________________________________________
# sequential_85 (Sequential)      (None, 5, 5, 126)    17784       add_2[0][0]
# __________________________________________________________________________________________________
# sequential_87 (Sequential)      (None, 3, 3, 84)     12240       add_1[0][0]
# __________________________________________________________________________________________________
# sequential_89 (Sequential)      (None, 2, 2, 84)     12240       concatenate_28[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 8664, 21)     0           sequential_79[1][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 2166, 21)     0           sequential_81[1][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 600, 21)      0           sequential_83[1][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 150, 21)      0           sequential_85[1][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 36, 21)       0           sequential_87[1][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 16, 21)       0           sequential_89[1][0]
# __________________________________________________________________________________________________
# sequential_78 (Sequential)      (None, 38, 38, 24)   4320        add_5[0][0]
# __________________________________________________________________________________________________
# sequential_80 (Sequential)      (None, 19, 19, 24)   4320        add_4[0][0]
# __________________________________________________________________________________________________
# sequential_82 (Sequential)      (None, 10, 10, 24)   4320        add_3[0][0]
# __________________________________________________________________________________________________
# sequential_84 (Sequential)      (None, 5, 5, 24)     4320        add_2[0][0]
# __________________________________________________________________________________________________
# sequential_86 (Sequential)      (None, 3, 3, 16)     3264        add_1[0][0]
# __________________________________________________________________________________________________
# sequential_88 (Sequential)      (None, 2, 2, 16)     3264        concatenate_28[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 11632, 21)    0           reshape_2[0][0]
#                                                                  reshape_4[0][0]
#                                                                  reshape_6[0][0]
#                                                                  reshape_8[0][0]
#                                                                  reshape_10[0][0]
#                                                                  reshape_12[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 8664, 4)      0           sequential_78[1][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 2166, 4)      0           sequential_80[1][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 600, 4)       0           sequential_82[1][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 150, 4)       0           sequential_84[1][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 36, 4)        0           sequential_86[1][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 16, 4)        0           sequential_88[1][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, 11632, 21)    0           concatenate_30[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 11632, 4)     0           reshape_1[0][0]
#                                                                  reshape_3[0][0]
#                                                                  reshape_5[0][0]
#                                                                  reshape_7[0][0]
#                                                                  reshape_9[0][0]
#                                                                  reshape_11[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 11632, 25)    0           softmax_1[0][0]
#                                                                  concatenate_29[0][0]
# ==================================================================================================
# Total params: 1,009,344
# Trainable params: 997,248
# Non-trainable params: 12,096
# __________________________________________________________________________________________________
# rfblite_mn2_300_b has been built

# %% [markdown]
# ### Load previously trained models

# %%
K.clear_session() # Clear previous models from memory.

model_path = "test.h5"#"saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-09_loss-3.8606_val_loss-3.8860.h5"
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
ssd_loss = SSDLoss(neg_pos_ratio=3,alpha=1.0)

# model = multi_gpu_model(model,gpus=2) #Comment it if don`t use multi_gpu 
model = load_model(model_path,custom_objects={'loss': ssd_loss.loss,'class_loss':ssd_loss.class_loss,'loc_loss':ssd_loss.loc_loss})
print("load model from",model_path)
# Out:
# load model from test.h5

# %% [markdown]
# ### Data config

# %%
feature_map_300 = [38,19,10,5,3,2]
feature_map_224 = [7,7,4,4,2,1]

#Define class_names
class_names = ['background',
           'aeroplane', 'bicycle', 'bird', 'boat',
           'bottle', 'bus', 'car', 'cat',
           'chair', 'cow', 'diningtable', 'dog',
           'horse', 'motorbike', 'person', 'pottedplant',
           'sheep', 'sofa', 'train', 'tvmonitor']

force_create_dataset = False #Force data generator to load dataset from source
root_path = '/home/cai/dataset/VOCdevkit'
trainset_hdf5_path = 'dataset_pascal_voc_07+12_trainval.h5'
valset_hdf5_path = 'dataset_pascal_voc_07_test.h5'

# The directories that contain the images.
VOC_2007_images_dir      = root_path + '/VOC2007/JPEGImages/'
VOC_2012_images_dir      = root_path + '/VOC2012/JPEGImages/'

# The directories that contain the annotations.
VOC_2007_annotations_dir      = root_path + '/VOC2007/Annotations/'
VOC_2012_annotations_dir      = root_path + '/VOC2012/Annotations/'

# The paths to the image sets.
VOC_2007_train_image_set_filename    = root_path + '/VOC2007/ImageSets/Main/train.txt'
VOC_2012_train_image_set_filename    = root_path + '/VOC2012/ImageSets/Main/train.txt'
VOC_2007_val_image_set_filename      = root_path + '/VOC2007/ImageSets/Main/val.txt'
VOC_2012_val_image_set_filename      = root_path + '/VOC2012/ImageSets/Main/val.txt'
VOC_2007_trainval_image_set_filename = root_path + '/VOC2007/ImageSets/Main/trainval.txt'
VOC_2012_trainval_image_set_filename = root_path + '/VOC2012/ImageSets/Main/trainval.txt'
VOC_2007_test_image_set_filename     = root_path + '/VOC2007/ImageSets/Main/test.txt'

# %% [markdown]
# ## Load Dataset

# %%
if os.path.isfile(trainset_hdf5_path) and os.path.isfile(valset_hdf5_path) and not force_create_dataset:
    #Load dataset from created hdf5_dataset
    train_dataset = DataGenerator(hdf5_dataset_path = trainset_hdf5_path)
    val_dataset = DataGenerator(hdf5_dataset_path = valset_hdf5_path)
else:
    train_dataset = DataGenerator()
    val_dataset = DataGenerator()
    
    train_dataset.parse_xml(images_dirs=[VOC_2007_images_dir,
                                         VOC_2012_images_dir],
                            image_set_filenames=[VOC_2007_trainval_image_set_filename,
                                                 VOC_2012_trainval_image_set_filename],
                            annotations_dirs=[VOC_2007_annotations_dir,
                                              VOC_2012_annotations_dir],
                            classes=class_names,
                            include_classes='all',
                            exclude_truncated=False,
                            exclude_difficult=False,
                            ret=False)

    val_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                          image_set_filenames=[VOC_2007_test_image_set_filename],
                          annotations_dirs=[VOC_2007_annotations_dir],
                          classes=class_names,
                          include_classes='all',
                          exclude_truncated=False,
                          exclude_difficult=True,
                          ret=False)
    train_dataset.create_hdf5_dataset(file_path=trainset_hdf5_path,
                                      resize=False,
                                      variable_image_size=True,
                                      verbose=True)

    val_dataset.create_hdf5_dataset(file_path=valset_hdf5_path,
                                    resize=False,
                                    variable_image_size=True,
                                    verbose=True)
# Out:
# Loading labels: 100%|██████████| 16551/16551 [00:04<00:00, 4070.19it/s]
# Loading image IDs: 100%|██████████| 16551/16551 [00:01<00:00, 9224.86it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 16551/16551 [00:02<00:00, 6866.73it/s]
# Loading labels: 100%|██████████| 4952/4952 [00:01<00:00, 4100.42it/s]
# Loading image IDs: 100%|██████████| 4952/4952 [00:00<00:00, 9121.95it/s]
# Loading evaluation-neutrality annotations: 100%|██████████| 4952/4952 [00:00<00:00, 6936.74it/s]

# %% [markdown]
# ## Data Augment

# %%
import detector_help
reload(detector_help)
from detector_help import *
import data_augment
reload(data_augment)
from data_augment import *

batch_size = 32
ssd_data_augmentation = SSDDataAugmentation(img_height=input_H,
                                            img_width=input_W,
                                            background=mean_color)

# For the validation generator:
convert_to_3_channels = ConvertTo3Channels()
resize = Resize(height=input_H, width=input_W)

# 5: Instantiate an encoder that can encode ground truth labels into the format needed by the SSD loss function.

# The encoder constructor needs the spatial dimensions of the model's predictor layers to create the anchor boxes.
priors = prior_box(feature_map_300,aspect_ratios,scale = scale)
label_encoder = LabelEncoder(num_classes,priors,variances,input_H,input_W)

# 6: Create the generator handles that will be passed to Keras' `fit_generator()` function.

train_generator = train_dataset.generate(batch_size=batch_size,
                                         shuffle=True,
                                         transformations=[ssd_data_augmentation],
                                         label_encoder=label_encoder,
                                         returns={'processed_images',
                                                  'encoded_labels'},
                                         keep_images_without_gt=False)

val_generator = val_dataset.generate(batch_size=batch_size,
                                     shuffle=False,
                                     transformations=[convert_to_3_channels,
                                                      resize],
                                     label_encoder=label_encoder,
                                     returns={'processed_images',
                                              'encoded_labels'},
                                     keep_images_without_gt=False)

# Get the number of samples in the training and validations datasets.
train_dataset_size = train_dataset.get_dataset_size()
val_dataset_size   = val_dataset.get_dataset_size()
print("Number of priors:\t{:>6}".format(len(priors)))
print("Number of images in the training dataset:\t{:>6}".format(train_dataset_size))
print("Number of images in the validation dataset:\t{:>6}".format(val_dataset_size))
# Out:
# Number of priors:	 11632
# Number of images in the training dataset:	 16551
# Number of images in the validation dataset:	  4952

# %% [markdown]
# ## Define callback function

# %%
#1. Set file path
weights_folder = 'saved_weights/'

if not os.path.isdir(weights_folder):
    os.mkdir(weights_folder)

checkpoint_filepath = weights_folder + model_name + '_pascal_07+12_epoch-{epoch:02d}_loss-{loss:.4f}_val_loss-{val_loss:.4f}.h5'
log_filepath = model_name + '_pascal_07+12_training_log.csv' 
#2. Define lr schedule function
def lr_schedule(epoch):
    if epoch < 40:
        return 0.001
    elif epoch < 70:
        return 0.0001
    else:
        return 1e-5
    
#3. ## Define callbacks
model_checkpoint = ModelCheckpoint(filepath = checkpoint_filepath,
                                   monitor='val_loss',
                                   verbose=1,
                                   save_best_only=True,
                                   save_weights_only=False,
                                   mode='auto',
                                   period=1)

csv_logger = CSVLogger(filename=log_filepath,
                           separator=',',
                           append=True)

learning_rate_scheduler = LearningRateScheduler(schedule=lr_schedule,
                                                verbose=1)

terminate_on_nan = TerminateOnNaN()

callbacks = [model_checkpoint,
             csv_logger,
             learning_rate_scheduler,
             terminate_on_nan]
# callbacks = [csv_logger,learning_rate_scheduler]

# %% [markdown]
# ## Draw a batch of images(optional)

# %%
train_flow_origin = train_dataset.generate(batch_size = 4,
                                           transformations=[], 
                                           label_encoder = label_encoder,
                                           returns = ['original_images','original_labels'])
images,labels = next(train_flow_origin)
for img,label in zip(images, labels):
    draw_detection(img,label,class_names)

# %% [markdown]
# ### Set training params

# %%
#If load weights from files,initial_epoch need to be set to the next epoch to be trained.
initial_epoch =0
final_epochs = 100
steps_per_epoch = 1000
plot = True

# %% [markdown]
# ## Train the model

# %%
print('model name' ,model_name , \
       '\nstart fitting.. ' , 
       'inital epoch:', initial_epoch,
       'final epoch:', final_epochs,
       'epoch step:', steps_per_epoch,
       'plot_history:' ,plot, \
       '\ntrainset size:',  train_dataset.get_dataset_size(), ' batch_size', batch_size )     

validation_steps =  val_dataset.get_dataset_size() // batch_size
history = model.fit_generator(train_generator,
                              use_multiprocessing = False, 
                              steps_per_epoch = steps_per_epoch, 
                              validation_data = val_generator,
                              validation_steps = validation_steps, 
                              epochs = final_epochs,
                              callbacks = callbacks,
                              initial_epoch = initial_epoch)

if plot:
    plot_history(history)
    plt.savefig('./%s_pascal07+12.jpg'%model_name)
# Out:
# model name rfblite_mn2_300_b
# start fitting..  inital epoch: 0 final epoch: 100 epoch step: 1000 plot_history: True
# trainset size: 16551  batch_size 32
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 812s 812ms/step - loss: 12.2820 - class_loss: 10.1536 - loc_loss: 1.8851 - val_loss: 13.6124 - val_class_loss: 9.8778 - val_loc_loss: 3.5694
#
# Epoch 00001: val_loss improved from inf to 13.61242, saving model to saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-01_loss-12.2826_val_loss-13.6124.h5
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 796s 796ms/step - loss: 7.7294 - class_loss: 6.0462 - loc_loss: 1.5533 - val_loss: 7.3069 - val_class_loss: 5.4649 - val_loc_loss: 1.7368
#
# Epoch 00002: val_loss improved from 13.61242 to 7.30690, saving model to saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-02_loss-7.7283_val_loss-7.3069.h5
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 798s 798ms/step - loss: 5.7701 - class_loss: 4.2362 - loc_loss: 1.4404 - val_loss: 6.0014 - val_class_loss: 4.2313 - val_loc_loss: 1.6844
#
# Epoch 00003: val_loss improved from 7.30690 to 6.00136, saving model to saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-03_loss-5.7697_val_loss-6.0014.h5
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.9831 - class_loss: 3.5248 - loc_loss: 1.3762 - val_loss: 5.7614 - val_class_loss: 3.9825 - val_loc_loss: 1.6991
#
# Epoch 00004: val_loss improved from 6.00136 to 5.76139, saving model to saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-04_loss-4.9826_val_loss-5.7614.h5
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.6224 - class_loss: 3.2206 - loc_loss: 1.3231 - val_loss: 5.6038 - val_class_loss: 3.9074 - val_loc_loss: 1.6181
#
# Epoch 00005: val_loss improved from 5.76139 to 5.60377, saving model to saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-05_loss-4.6223_val_loss-5.6038.h5
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.4012 - class_loss: 3.0509 - loc_loss: 1.2724 - val_loss: 5.1401 - val_class_loss: 3.5799 - val_loc_loss: 1.4828
#
# Epoch 00006: val_loss improved from 5.60377 to 5.14006, saving model to saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-06_loss-4.4010_val_loss-5.1401.h5
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 793s 793ms/step - loss: 4.2384 - class_loss: 2.9348 - loc_loss: 1.2260 - val_loss: 4.5368 - val_class_loss: 3.0726 - val_loc_loss: 1.3866
#
# Epoch 00007: val_loss improved from 5.14006 to 4.53680, saving model to saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-07_loss-4.2376_val_loss-4.5368.h5
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 795s 795ms/step - loss: 4.1324 - class_loss: 2.8576 - loc_loss: 1.1977 - val_loss: 4.7283 - val_class_loss: 3.2039 - val_loc_loss: 1.4476
#
# Epoch 00008: val_loss did not improve from 4.53680
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 1000/1000 [==============================] - 797s 797ms/step - loss: 4.0598 - class_loss: 2.7980 - loc_loss: 1.1855 - val_loss: 4.3010 - val_class_loss: 2.9430 - val_loc_loss: 1.2821
#
# Epoch 00009: val_loss improved from 4.53680 to 4.30102, saving model to saved_weights/rfblite_mn2_300_b_pascal_07+12_epoch-09_loss-4.0585_val_loss-4.3010.h5
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
#  401/1000 [===========>..................] - ETA: 7:41 - loss: 3.9973 - class_loss: 2.7560 - loc_loss: 1.1654

# %% [markdown]
# ## Evaluate

# %% [markdown]
# ### Speed

# %%
import time
batch_n = 100
img_height = 300
img_width = 300
img_channels = 3
# detector = Detect(num_classes,0,cfg)
batch_size_range = [1,2,4,8,16,32]#[1,2,4,8]
print('Start testing...')
for batch_size in batch_size_range:
    time_total = 0
    time_net = 0
    time_post = 0
    print('batch size',batch_size)
    for i in range(0,batch_n):
        test_batch = np.random.rand(batch_size,img_height,img_width,img_channels)
        click = time.time()
        y_pred = model.predict(test_batch)
        time_net += (time.time() - click)
        click = time.time()
        y_pred_decoded = decode_detections(y_pred,
                          priors,variances,
                          img_height = input_H,
                          img_width = input_W,
                          confidence_thresh = 0.5,
                          iou_threshold = 0.45)
        time_post += (time.time() - click)
    time_total = time_net + time_post
    print('Time cost per batch: %.3f FPS: %.1f'%(time_total / batch_n,batch_n*batch_size/ time_total))
    print('Time(pure forward) cost per batch: %.3f FPS: %.1F'%(time_net / batch_n, batch_n*batch_size/ time_net))
# Out:
# Start testing...
# batch size 1
# Time cost per batch: 0.036 FPS: 27.9
# Time(pure forward) cost per batch: 0.025 FPS: 39.7
# batch size 2
# Time cost per batch: 0.051 FPS: 39.1
# Time(pure forward) cost per batch: 0.030 FPS: 66.1
# batch size 4
# Time cost per batch: 0.077 FPS: 52.2
# Time(pure forward) cost per batch: 0.035 FPS: 113.6
# batch size 8
# Time cost per batch: 0.147 FPS: 54.3
# Time(pure forward) cost per batch: 0.057 FPS: 139.5
# batch size 16
# Time cost per batch: 0.250 FPS: 64.1
# Time(pure forward) cost per batch: 0.104 FPS: 154.2
# batch size 32
# Time cost per batch: 0.463 FPS: 69.2
# Time(pure forward) cost per batch: 0.206 FPS: 155.1

# %% [markdown]
# ### mAP

# %%
import eval_utils.average_precision_evaluator
reload(eval_utils.average_precision_evaluator)
from eval_utils.average_precision_evaluator import Evaluator

# %%
test_dataset.parse_xml(images_dirs=[VOC_2007_images_dir],
                      image_set_filenames=[VOC_2007_test_image_set_filename],
                      annotations_dirs=[VOC_2007_annotations_dir],
                      classes=class_names,
                      include_classes='all',
                      exclude_truncated=False,
                      exclude_difficult=False,
                      ret=False)

print('Test size', test_dataset.get_dataset_size())

# %%
evaluator = Evaluator(model=model,
                      n_classes=num_classes,
                      data_generator=test_dataset,
                      model_mode='training')

results = evaluator(img_height=input_H,
                    img_width=input_W,
                    batch_size=batch_size,
                    priors = priors,
                    variances = variances,
                    data_generator_mode='resize',
                    round_confidences=False,
                    matching_iou_threshold=0.5,
                    border_pixels='include',
                    sorting_algorithm='quicksort',
                    average_precision_mode='sample',
                    num_recall_points=11,
                    ignore_neutral_boxes=True,
                    return_precisions=True,
                    return_recalls=True,
                    return_average_precisions=True,
                    verbose=True)

mean_average_precision, average_precisions, precisions, recalls = results

# %%
for i in range(1, len(average_precisions)):
    print("{:<14}{:<6}{}".format(class_names[i], 'AP', round(average_precisions[i], 3)))
print()
print("{:<14}{:<6}{}".format('','mAP', round(mean_average_precision, 3)))

# %%
m = max((num_classes + 1) // 2, 2)
n = 2

fig, cells = plt.subplots(m, n, figsize=(n*8,m*8))
for i in range(m):
    for j in range(n):
        if n*i+j+1 > num_classes: break
        cells[i, j].plot(recalls[n*i+j+1], precisions[n*i+j+1], color='blue', linewidth=1.0)
        cells[i, j].set_xlabel('recall', fontsize=14)
        cells[i, j].set_ylabel('precision', fontsize=14)
        cells[i, j].grid(True)
        cells[i, j].set_xticks(np.linspace(0,1,11))
        cells[i, j].set_yticks(np.linspace(0,1,11))
        cells[i, j].set_title("{}, AP: {:.3f}".format(class_names[n*i+j+1], average_precisions[n*i+j+1]), fontsize=16)

# %% [markdown]
# ### Predict

# %%
# 1: Set the generator for the predictions.

predict_generator = val_dataset.generate(batch_size=1,
                                         shuffle=True,
                                         transformations=[convert_to_3_channels,
                                                          resize],
                                         label_encoder=None,
                                         returns={'processed_images',
                                                  'inverse_transform',
                                                  'original_images',
                                                  'original_labels'},
                                         keep_images_without_gt=False)

# %%
# Generate batch_items
batch_images, batch_inverse_transforms, batch_original_images, batch_original_labels = next(predict_generator)

i = 0 # Which batch item to look at

#print("Image:", batch_filenames[i])
print()
print("Ground truth boxes:\n")
print(np.array(batch_original_labels[i]))


# 3: Make predictions.
y_pred = model.predict(batch_images)

# %%
# 4: Decode labels
reload(detector_help)
y_pred_decoded = decode_detections(y_pred,
                  priors,variances,
                  img_height = input_H,
                  img_width = input_W,
                  confidence_thresh = 0.1,
                  iou_threshold = 0.45)
# y_pred_decoded = detector_help.post_process(y_pred, 
#                                             priors,
#                                             num_classes,
#                                             input_H, 
#                                             input_W,
#                                             score_thresh = 0.5,
#                                             iou_thresh = 0.4)
y_pred_decoded_inv = apply_inverse_transforms(y_pred_decoded, batch_inverse_transforms)
np.set_printoptions(precision=2, suppress=True, linewidth=90)
print("Predicted boxes:\n")
print('   class   conf xmin   ymin   xmax   ymax')
print(y_pred_decoded_inv[i])

# %%
# 5: Draw 
colors = plt.cm.hsv(np.linspace(0, 1, num_classes+1)).tolist()
draw_detection(batch_original_images[i],y_pred_decoded_inv[i],class_names,
               show = True, draw_score = True,use_cm = True,color = colors, size = 'medium')
draw_detection(batch_original_images[i],batch_original_labels[i],class_names, size = 'medium')

# %% [markdown]
# ### Image Demo

# %%
img_file = "data/dog3.jpg"
img = cv2.imread(img_file)
img = cv2.resize(img,(224,224))
x = cv2.resize(img, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
x = np.array(x,dtype='float')
x = x / 255
y_pred = model.predict(np.expand_dims(x,0))
y_pred = post_process(y_pred,priors,num_classes,input_H,input_W)
print(y_pred)
draw_detection(img,y_pred[0],class_names)

# %% [markdown]
# ### Video detection demo

# %%
video_file = "data/cat_video.mp4"
result_file = "res.avi"
cap= cv2.VideoCapture(video_file)
fps = cap.get(cv2.CAP_PROP_FPS)
size = (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
frames = (int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print('Input Video Size:',size,' Fps:',fps,' Frames:',frames)
writer = cv2.VideoWriter(result_file,cv2.VideoWriter_fourcc(*'MJPG'), fps, size)
success,frame = cap.read()
count = 1
while success:
    x = cv2.resize(frame,dsize=(input_H,input_W),interpolation=cv2.INTER_CUBIC)
    x = x / 255
    y_pred = model.predict(np.expand_dims(x,0))[0]
    y_pred [-4:] *= [*size,*size]
    draw_detection(frame, y_pred,class_names,font_scale = 1)
    writer.write(frame)
    cv2.waitKey(1)
    count += 1
    if count%50==0:
        print(y_pred)
        plt.imshow(frame)
        plt.show()
        print('.',end='')
    success,frame = cap.read()
print('done')
